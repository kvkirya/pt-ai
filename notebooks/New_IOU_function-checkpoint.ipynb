# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from shapely.geometry import Polygon
import numpy as np

# %%
import json

with open('/Users/abou48862/code/kvkirya/pt-ai/raw_data/annotations.json') as json_data:
    data = json.load(json_data)

# %%
df_images = pd.DataFrame(data["images"])
df_annotations = pd.DataFrame(data["annotations"])

# %%
df_images
# Out:
#        license     id         file_name  width  height  \
# 0            0      1  00000001.rgb.png    640     480
# 1            0      2  00000002.rgb.png    640     480
# 2            0      3  00000003.rgb.png    640     480
# 3            0      4  00000004.rgb.png    640     480
# 4            0      5  00000005.rgb.png    640     480
# ...        ...    ...               ...    ...     ...
# 59573        0  59574  00059574.rgb.png    640     480
# 59574        0  59575  00059575.rgb.png    640     480
# 59575        0  59576  00059576.rgb.png    640     480
# 59576        0  59577  00059577.rgb.png    640     480
# 59577        0  59578  00059578.rgb.png    640     480
#
#                          hdri_name  hdri_rotation_deg  camera_rotation_deg
# 0         construction_yard_4k.hdr         262.228967            78.472965
# 1         construction_yard_4k.hdr         167.524583            67.888454
# 2         construction_yard_4k.hdr          10.682487            73.478342
# 3         construction_yard_4k.hdr          27.743320            72.287580
# 4         construction_yard_4k.hdr         107.101225            68.926178
# ...                            ...                ...                  ...
# 59573    empty_warehouse_01_4k.hdr         321.167844            70.070446
# 59574    empty_warehouse_01_4k.hdr         124.626978            63.659398
# 59575    empty_warehouse_01_4k.hdr         237.013957            48.973143
# 59576    empty_warehouse_01_4k.hdr         150.917579            70.161267
# 59577  abandoned_waterworks_4k.hdr         266.471388            78.559729
#
# [59578 rows x 8 columns]

# %%
df_annotations
# Out:
#         category_id  image_id      id  iscrowd  \
# 0                 0         1       1        0
# 1                 0         1       2        0
# 2                 0         1       3        0
# 3                 0         2       4        0
# 4                 0         2       5        0
# ...             ...       ...     ...      ...
# 167939            0     59577  167940        0
# 167940            0     59578  167941        0
# 167941            0     59578  167942        0
# 167942            0     59578  167943        0
# 167943            0     59578  167944        0
#
#                                                     color        area  \
# 0       [0.09803921568627451, 0.09803921568627451, 0.4...   3075.7804
# 1       [0.8274509803921568, 0.8666666666666667, 0.894...   2857.8604
# 2                          [0.5333333333333333, 1.0, 0.8]   6313.9804
# 3       [0.09803921568627451, 0.09803921568627451, 0.4...  10207.9404
# 4       [0.13333333333333333, 0.3333333333333333, 0.46...  23513.2404
# ...                                                   ...         ...
# 167939  [0.8274509803921568, 0.8666666666666667, 0.894...   8632.1004
# 167940  [0.09803921568627451, 0.09803921568627451, 0.4...  32710.4204
# 167941  [0.13333333333333333, 0.3333333333333333, 0.46...   5325.0804
# 167942                                    [0.6, 0.0, 0.4]   5239.8804
# 167943  [0.8274509803921568, 0.8666666666666667, 0.894...   7736.4804
#
#                                              segmentation  \
# 0       [[493.0, 240.99, 485.01, 236.0, 484.0, 227.99,...
# 1       [[151.0, 239.99, 148.0, 239.99, 146.01, 238.0,...
# 2       [[327.0, 258.99, 321.0, 258.99, 319.01, 257.0,...
# 3       [[486.0, 185.99, 484.01, 182.0, 486.0, 180.01,...
# 4       [[548.0, 338.99, 543.0, 338.99, 541.0, 336.99,...
# ...                                                   ...
# 167939  [[494.0, 296.99, 487.0, 294.99, 484.0, 291.99,...
# 167940  [[453.0, 354.99, 447.0, 351.99, 440.0, 351.99,...
# 167941  [[319.0, 210.99, 316.0, 210.99, 307.0, 205.99,...
# 167942  [[332.0, 249.99, 323.0, 247.99, 317.0, 241.99,...
# 167943  [[202.0, 236.99, 199.0, 236.99, 191.0, 232.99,...
#
#                                                      bbox  num_keypoints  \
# 0       [439.01, 187.01, 56.98000000000002, 53.9800000...             14
# 1       [142.01, 185.01, 51.98000000000002, 54.9800000...             14
# 2       [302.01, 97.01, 38.98000000000002, 161.9800000...             14
# 3             [477.01, 113.01, 110.98000000000002, 91.98]             14
# 4       [506.01, 99.01, 97.98000000000002, 239.9800000...             14
# ...                                                   ...            ...
# 167939  [398.01, 229.01, 126.98000000000002, 67.980000...             14
# 167940  [249.01, 222.01, 245.98000000000002, 132.98000...             14
# 167941  [290.01, 137.01, 71.98000000000002, 73.9800000...             14
# 167942  [297.01, 201.01, 106.98000000000002, 48.980000...             14
# 167943  [188.01, 151.01, 89.98000000000002, 85.9800000...             14
#
#                                                 keypoints  ... pose_category  \
# 0       [0, 0, 0, 469, 193, 2, 465, 193, 2, 0, 0, 0, 0...  ...         situp
# 1       [0, 0, 0, 167, 188, 2, 163, 188, 2, 0, 0, 0, 0...  ...         situp
# 2       [0, 0, 0, 324, 116, 2, 321, 116, 2, 0, 0, 0, 0...  ...          tree
# 3       [0, 0, 0, 485, 128, 2, 483, 132, 2, 0, 0, 0, 0...  ...     sideplank
# 4       [0, 0, 0, 577, 120, 2, 567, 118, 2, 0, 0, 0, 0...  ...         curls
# ...                                                   ...  ...           ...
# 167939  [0, 0, 0, 410, 263, 2, 411, 265, 2, 0, 0, 0, 0...  ...     hipbridge
# 167940  [0, 0, 0, 484, 250, 2, 482, 252, 2, 0, 0, 0, 0...  ...         plank
# 167941  [0, 0, 0, 297, 193, 2, 296, 193, 2, 0, 0, 0, 0...  ...      legraise
# 167942  [0, 0, 0, 308, 229, 2, 306, 230, 2, 0, 0, 0, 0...  ...     hipbridge
# 167943  [0, 0, 0, 275, 167, 2, 274, 163, 2, 0, 0, 0, 0...  ...     sideplank
#
#        exercise_category                                      cuboid_points  \
# 0                 [HIIT]  [[438, 186], [484, 186], [502, 194], [451, 194...
# 1                 [HIIT]  [[143, 184], [194, 184], [181, 191], [124, 191...
# 2                 [Yoga]  [[301, 93], [340, 93], [342, 91], [300, 91], [...
# 3           [Yoga, HIIT]  [[478, 109], [580, 109], [613, 124], [497, 124...
# 4                 [HIIT]  [[512, 95], [603, 95], [632, 106], [531, 106],...
# ...                  ...                                                ...
# 167939      [Yoga, HIIT]  [[392, 223], [506, 218], [552, 251], [419, 257...
# 167940      [Yoga, HIIT]  [[255, 202], [466, 203], [505, 229], [232, 227...
# 167941            [HIIT]  [[293, 136], [360, 136], [364, 139], [286, 139...
# 167942      [Yoga, HIIT]  [[298, 198], [413, 199], [420, 206], [294, 206...
# 167943      [Yoga, HIIT]  [[207, 150], [278, 150], [267, 156], [182, 156...
#
#        zaxis_rotation_deg   attire_top  attire_bottom presenting_gender  \
# 0               15.061740  raglanshirt          track            female
# 1                0.801464  raglanshirt         tights              male
# 2              -70.690204       tshirt          jeans              male
# 3              -32.316700  raglanshirt          track            female
# 4              -32.057216       tshirt          jeans              male
# ...                   ...          ...            ...               ...
# 167939          78.247364       tshirt          track            female
# 167940          65.123053  raglanshirt         shorts              male
# 167941          76.773370         tank         shorts              male
# 167942          78.301114         tank         shorts              male
# 167943          55.519683         tank         tights              male
#
#        waist_circumference    height  \
# 0                 0.730767  1.649463
# 1                 0.852622  1.753723
# 2                 0.990933  1.766118
# 3                 1.104884  1.744472
# 4                 0.935389  1.854919
# ...                    ...       ...
# 167939            0.951058  1.687193
# 167940            1.046934  1.855765
# 167941            0.893962  1.794887
# 167942            0.818586  1.795573
# 167943            0.876724  1.819273
#
#                                                     betas
# 0       [-0.03959597647190094, -0.5644581913948059, 0....
# 1       [0.7923352718353271, -1.2788528203964233, 1.24...
# 2       [0.33408355712890625, 0.24142998456954956, -0....
# 3       [1.1612275838851929, 0.8204484581947327, -1.58...
# 4       [-0.7777438163757324, -0.040555573999881744, -...
# ...                                                   ...
# 167939  [0.6385455131530762, 0.829331636428833, 0.9691...
# 167940  [-0.7987443804740906, 0.29380616545677185, 0.8...
# 167941  [0.008171923458576202, 0.0021372123155742884, ...
# 167942  [0.2891143262386322, -1.4047441482543945, 0.37...
# 167943  [-0.1799926608800888, -0.5455002188682556, -0....
#
# [167944 rows x 22 columns]

# %%
df_annotations.drop(columns = "id", axis = 0, inplace = True)
df_annotations.rename(columns = {"image_id" : "id"}, inplace = True)
len(df_annotations)
# Out:
# 167944

# %%
#dataset with every single different character in it
df_complete = pd.merge(df_annotations, df_images, on = "id")
df_complete = df_complete[['id', 'file_name', 'pose_variation',
       'pose_category', 'exercise_category', 'bbox', "camera_rotation_deg"]]
df_complete.iloc[0:6]
# Out:
#    id         file_name   pose_variation pose_category exercise_category  \
# 0   1  00000001.rgb.png            situp         situp            [HIIT]
# 1   1  00000001.rgb.png            situp         situp            [HIIT]
# 2   1  00000001.rgb.png       tree_right          tree            [Yoga]
# 3   2  00000002.rgb.png  sideplank_right     sideplank      [Yoga, HIIT]
# 4   2  00000002.rgb.png      curls_right         curls            [HIIT]
# 5   2  00000002.rgb.png            updog         updog            [Yoga]
#
#                                                 bbox  camera_rotation_deg
# 0  [439.01, 187.01, 56.98000000000002, 53.9800000...            78.472965
# 1  [142.01, 185.01, 51.98000000000002, 54.9800000...            78.472965
# 2  [302.01, 97.01, 38.98000000000002, 161.9800000...            78.472965
# 3        [477.01, 113.01, 110.98000000000002, 91.98]            67.888454
# 4  [506.01, 99.01, 97.98000000000002, 239.9800000...            67.888454
# 5                      [56.01, 118.01, 44.98, 67.98]            67.888454

# %%
#so now we need to check wether overlaps
#the bounding boxes are in COCO format so [x_min, y_min, width, height]

#convert coco to pascal_voc so to [x_min, y_min, x_max, y_max]
def coco_to_pascal(X):
    return [X[0], X[1], X[0] + X[2], X[1] + X[3]]

# %%
coco_to_pascal([439.01, 187.01, 56.98000000000002, 53.98000000000002])
# Out:
# [439.01, 187.01, 495.99, 240.99]

# %%
df_complete["bbox_pascal"] = df_complete["bbox"].apply(coco_to_pascal)
df_complete["index"] = range(1, len(df_complete)+1)

# %%
df_complete.iloc[0:6]
# Out:
#    id         file_name   pose_variation pose_category exercise_category  \
# 0   1  00000001.rgb.png            situp         situp            [HIIT]
# 1   1  00000001.rgb.png            situp         situp            [HIIT]
# 2   1  00000001.rgb.png       tree_right          tree            [Yoga]
# 3   2  00000002.rgb.png  sideplank_right     sideplank      [Yoga, HIIT]
# 4   2  00000002.rgb.png      curls_right         curls            [HIIT]
# 5   2  00000002.rgb.png            updog         updog            [Yoga]
#
#                                                 bbox  camera_rotation_deg  \
# 0  [439.01, 187.01, 56.98000000000002, 53.9800000...            78.472965
# 1  [142.01, 185.01, 51.98000000000002, 54.9800000...            78.472965
# 2  [302.01, 97.01, 38.98000000000002, 161.9800000...            78.472965
# 3        [477.01, 113.01, 110.98000000000002, 91.98]            67.888454
# 4  [506.01, 99.01, 97.98000000000002, 239.9800000...            67.888454
# 5                      [56.01, 118.01, 44.98, 67.98]            67.888454
#
#                         bbox_pascal  index
# 0  [439.01, 187.01, 495.99, 240.99]      1
# 1  [142.01, 185.01, 193.99, 239.99]      2
# 2   [302.01, 97.01, 340.99, 258.99]      3
# 3  [477.01, 113.01, 587.99, 204.99]      4
# 4   [506.01, 99.01, 603.99, 338.99]      5
# 5   [56.01, 118.01, 100.99, 185.99]      6

# %%
from collections import namedtuple

# %%
Rectangle = namedtuple("Rectangle", "xmin ymin xmax ymax")
#we can turn the bbox column into rectangles with an apply function, so that they can be used directly in
#the iou function

# %%
rect_1 = Rectangle(1, 2, 3, 4)
rect_1.xmax
# Out:
# 3

# %%
#the all in one function!!!!
#the function takes in two rectangles and outputs the percentage iou
#bbox is in format [xmin, ymin, width, height]
def the_function(bbox1, bbox2): 
    a = Rectangle(bbox1[0], bbox1[1], bbox1[2], bbox1[3])
    b = Rectangle(bbox2[0], bbox2[1], bbox2[2], bbox2[3])
    
    #first we calculate the individual areas of the two rectangles
    area_a = (max(a.xmin, a.xmax) - min(a.xmin, a.xmax)) * (max(a.ymin, a.ymax) - min(a.ymin, a.ymax))
    area_b = (max(b.xmin, b.xmax) - min(b.xmin, b.xmax)) * (max(b.ymin, b.ymax) - min(b.ymin, b.ymax))
    
    #we then calculate the intersection area of the two rectangles
    diff_x = min(a.xmax, b.xmax) - max(a.xmin, b.xmin)
    diff_y =  min(a.ymax, b.ymax) - max(a.ymin, b.ymin)
    intersection_area = max(0, diff_x)* max(0, diff_y)
    
    #we then calculate the percentage intersection, which we return
    return intersection_area / (area_a+area_b-intersection_area)

# %%
rect_1 = [302.01, 97.01, 340.99, 258.99]
rect_2 = [439.01, 187.01, 495.99, 240.99]

# %%
the_function(rect_1, rect_2)
# Out:
# 0.0

# %%
the_function(rect_1, rect_1)
# Out:
# 1.0

# %%
new_box_1 = coco_to_pascal(box1)

# %%
x_left, y_top, x_right, y_bottom = int(new_box_1[0]), int(new_box_1[1]),  int(new_box_1[2]), int(new_box_1[3])

# %% [markdown]
# ## Code to filter images before cropping

# %%
import os
import shutil

# %%
filename = df_complete['file_name']
pose_variations = df_complete['pose_variation']

filenames =filename.to_list()
clean_files = []

# %%
for file, pose_variation in zip(filenames, pose_variations):
    if file.endswith('.rgb.png'):
        clean_files.append((file, pose_variation))

# %%
clean_files
# Out:
# [('00000001.rgb.png', 'situp'),
#  ('00000001.rgb.png', 'situp'),
#  ('00000001.rgb.png', 'tree_right'),
#  ('00000002.rgb.png', 'sideplank_right'),
#  ('00000002.rgb.png', 'curls_right'),
#  ('00000002.rgb.png', 'updog'),
#  ('00000002.rgb.png', 'situp'),
#  ('00000003.rgb.png', 'squats'),
#  ('00000003.rgb.png', 'tree_right'),
#  ('00000004.rgb.png', 'legraise'),
#  ('00000004.rgb.png', 'pushups'),
#  ('00000005.rgb.png', 'tree_right'),
#  ('00000005.rgb.png', 'situp'),
#  ('00000005.rgb.png', 'updog'),
#  ('00000006.rgb.png', 'downdog'),
#  ('00000006.rgb.png', 'boatpose'),
#  ('00000007.rgb.png', 'downdog'),
#  ('00000007.rgb.png', 'situp'),
#  ('00000008.rgb.png', 'squats'),
#  ('00000009.rgb.png', 'plank'),
#  ('00000009.rgb.png', 'tree_right'),
#  ('00000009.rgb.png', 'curls_right'),
#  ('00000009.rgb.png', 'boatpose'),
#  ('00000010.rgb.png', 'tree_right'),
#  ('00000010.rgb.png', 'sideplank_right'),
#  ('00000010.rgb.png', 'pushups'),
#  ('00000010.rgb.png', 'squats'),
#  ('00000011.rgb.png', 'updog'),
#  ('00000011.rgb.png', 'lunge_left'),
#  ('00000011.rgb.png', 'updog'),
#  ('00000012.rgb.png', 'pushups'),
#  ('00000012.rgb.png', 'sideplank_left'),
#  ('00000013.rgb.png', 'jumpingjacks'),
#  ('00000014.rgb.png', 'situp'),
#  ('00000015.rgb.png', 'updog'),
#  ('00000015.rgb.png', 'updog'),
#  ('00000016.rgb.png', 'tree_left'),
#  ('00000016.rgb.png', 'jumpingjacks'),
#  ('00000016.rgb.png', 'squats'),
#  ('00000017.rgb.png', 'tree_left'),
#  ('00000017.rgb.png', 'pushups'),
#  ('00000017.rgb.png', 'boatpose'),
#  ('00000017.rgb.png', 'sideplank_left'),
#  ('00000017.rgb.png', 'curls_right'),
#  ('00000018.rgb.png', 'tree_left'),
#  ('00000018.rgb.png', 'downdog'),
#  ('00000018.rgb.png', 'legraise'),
#  ('00000018.rgb.png', 'tree_right'),
#  ('00000018.rgb.png', 'downdog'),
#  ('00000019.rgb.png', 'situp'),
#  ('00000019.rgb.png', 'squats'),
#  ('00000019.rgb.png', 'legraise'),
#  ('00000019.rgb.png', 'legraise'),
#  ('00000020.rgb.png', 'tree_right'),
#  ('00000020.rgb.png', 'pushups'),
#  ('00000020.rgb.png', 'hipbridge'),
#  ('00000020.rgb.png', 'boatpose'),
#  ('00000021.rgb.png', 'boatpose'),
#  ('00000021.rgb.png', 'jumpingjacks'),
#  ('00000021.rgb.png', 'curls_left'),
#  ('00000021.rgb.png', 'downdog'),
#  ('00000022.rgb.png', 'pushups'),
#  ('00000023.rgb.png', 'jumpingjacks'),
#  ('00000024.rgb.png', 'boatpose'),
#  ('00000024.rgb.png', 'pushups'),
#  ('00000024.rgb.png', 'curls_both'),
#  ('00000024.rgb.png', 'squats'),
#  ('00000025.rgb.png', 'squats'),
#  ('00000026.rgb.png', 'squats'),
#  ('00000027.rgb.png', 'downdog'),
#  ('00000027.rgb.png', 'curls_left'),
#  ('00000027.rgb.png', 'lunge_left'),
#  ('00000027.rgb.png', 'plank'),
#  ('00000028.rgb.png', 'jumpingjacks'),
#  ('00000029.rgb.png', 'boatpose'),
#  ('00000030.rgb.png', 'jumpingjacks'),
#  ('00000031.rgb.png', 'sideplank_left'),
#  ('00000032.rgb.png', 'legraise'),
#  ('00000032.rgb.png', 'downdog'),
#  ('00000032.rgb.png', 'situp'),
#  ('00000032.rgb.png', 'hipbridge'),
#  ('00000033.rgb.png', 'lunge_right'),
#  ('00000033.rgb.png', 'jumpingjacks'),
#  ('00000034.rgb.png', 'situp'),
#  ('00000035.rgb.png', 'warrior2_right'),
#  ('00000035.rgb.png', 'situp'),
#  ('00000035.rgb.png', 'hipbridge'),
#  ('00000036.rgb.png', 'curls_left'),
#  ('00000036.rgb.png', 'situp'),
#  ('00000037.rgb.png', 'pushups'),
#  ('00000037.rgb.png', 'jumpingjacks'),
#  ('00000037.rgb.png', 'plank'),
#  ('00000038.rgb.png', 'squats'),
#  ('00000038.rgb.png', 'curls_both'),
#  ('00000038.rgb.png', 'downdog'),
#  ('00000039.rgb.png', 'situp'),
#  ('00000039.rgb.png', 'sideplank_left'),
#  ('00000039.rgb.png', 'curls_right'),
#  ('00000039.rgb.png', 'warrior2_left'),
#  ('00000040.rgb.png', 'hipbridge'),
#  ('00000041.rgb.png', 'tree_right'),
#  ('00000041.rgb.png', 'lunge_left'),
#  ('00000042.rgb.png', 'boatpose'),
#  ('00000042.rgb.png', 'legraise'),
#  ('00000042.rgb.png', 'boatpose'),
#  ('00000043.rgb.png', 'curls_left'),
#  ('00000043.rgb.png', 'pushups'),
#  ('00000044.rgb.png', 'hipbridge'),
#  ('00000044.rgb.png', 'warrior2_left'),
#  ('00000044.rgb.png', 'lunge_right'),
#  ('00000045.rgb.png', 'hipbridge'),
#  ('00000045.rgb.png', 'sideplank_left'),
#  ('00000045.rgb.png', 'pushups'),
#  ('00000045.rgb.png', 'jumpingjacks'),
#  ('00000046.rgb.png', 'downdog'),
#  ('00000046.rgb.png', 'lunge_right'),
#  ('00000047.rgb.png', 'pushups'),
#  ('00000047.rgb.png', 'tree_left'),
#  ('00000047.rgb.png', 'squats'),
#  ('00000047.rgb.png', 'sideplank_left'),
#  ('00000048.rgb.png', 'curls_right'),
#  ('00000048.rgb.png', 'downdog'),
#  ('00000048.rgb.png', 'jumpingjacks'),
#  ('00000048.rgb.png', 'lunge_right'),
#  ('00000049.rgb.png', 'jumpingjacks'),
#  ('00000049.rgb.png', 'squats'),
#  ('00000050.rgb.png', 'warrior2_left'),
#  ('00000050.rgb.png', 'sideplank_left'),
#  ('00000050.rgb.png', 'legraise'),
#  ('00000051.rgb.png', 'sideplank_right'),
#  ('00000051.rgb.png', 'legraise'),
#  ('00000051.rgb.png', 'tree_left'),
#  ('00000051.rgb.png', 'situp'),
#  ('00000052.rgb.png', 'squats'),
#  ('00000052.rgb.png', 'pushups'),
#  ('00000053.rgb.png', 'updog'),
#  ('00000053.rgb.png', 'downdog'),
#  ('00000053.rgb.png', 'curls_right'),
#  ('00000054.rgb.png', 'tree_right'),
#  ('00000054.rgb.png', 'updog'),
#  ('00000054.rgb.png', 'situp'),
#  ('00000055.rgb.png', 'warrior2_right'),
#  ('00000055.rgb.png', 'jumpingjacks'),
#  ('00000056.rgb.png', 'plank'),
#  ('00000056.rgb.png', 'plank'),
#  ('00000056.rgb.png', 'hipbridge'),
#  ('00000056.rgb.png', 'legraise'),
#  ('00000057.rgb.png', 'sideplank_left'),
#  ('00000057.rgb.png', 'updog'),
#  ('00000057.rgb.png', 'downdog'),
#  ('00000058.rgb.png', 'lunge_left'),
#  ('00000058.rgb.png', 'pushups'),
#  ('00000058.rgb.png', 'boatpose'),
#  ('00000058.rgb.png', 'pushups'),
#  ('00000059.rgb.png', 'plank'),
#  ('00000059.rgb.png', 'boatpose'),
#  ('00000060.rgb.png', 'warrior2_right'),
#  ('00000060.rgb.png', 'plank'),
#  ('00000061.rgb.png', 'tree_right'),
#  ('00000061.rgb.png', 'pushups'),
#  ('00000061.rgb.png', 'pushups'),
#  ('00000061.rgb.png', 'sideplank_left'),
#  ('00000062.rgb.png', 'curls_both'),
#  ('00000062.rgb.png', 'pushups'),
#  ('00000062.rgb.png', 'tree_left'),
#  ('00000062.rgb.png', 'situp'),
#  ('00000063.rgb.png', 'warrior2_right'),
#  ('00000063.rgb.png', 'situp'),
#  ('00000063.rgb.png', 'downdog'),
#  ('00000064.rgb.png', 'pushups'),
#  ('00000064.rgb.png', 'lunge_right'),
#  ('00000064.rgb.png', 'pushups'),
#  ('00000064.rgb.png', 'boatpose'),
#  ('00000064.rgb.png', 'situp'),
#  ('00000065.rgb.png', 'sideplank_right'),
#  ('00000065.rgb.png', 'updog'),
#  ('00000065.rgb.png', 'jumpingjacks'),
#  ('00000065.rgb.png', 'squats'),
#  ('00000066.rgb.png', 'legraise'),
#  ('00000067.rgb.png', 'lunge_left'),
#  ('00000067.rgb.png', 'boatpose'),
#  ('00000067.rgb.png', 'lunge_right'),
#  ('00000068.rgb.png', 'situp'),
#  ('00000068.rgb.png', 'situp'),
#  ('00000068.rgb.png', 'updog'),
#  ('00000068.rgb.png', 'situp'),
#  ('00000069.rgb.png', 'squats'),
#  ('00000069.rgb.png', 'warrior2_left'),
#  ('00000069.rgb.png', 'boatpose'),
#  ('00000069.rgb.png', 'plank'),
#  ('00000069.rgb.png', 'sideplank_right'),
#  ('00000070.rgb.png', 'downdog'),
#  ('00000070.rgb.png', 'boatpose'),
#  ('00000070.rgb.png', 'warrior2_left'),
#  ('00000070.rgb.png', 'plank'),
#  ('00000071.rgb.png', 'lunge_left'),
#  ('00000071.rgb.png', 'situp'),
#  ('00000071.rgb.png', 'legraise'),
#  ('00000072.rgb.png', 'downdog'),
#  ('00000073.rgb.png', 'hipbridge'),
#  ('00000073.rgb.png', 'hipbridge'),
#  ('00000074.rgb.png', 'updog'),
#  ('00000074.rgb.png', 'lunge_left'),
#  ('00000074.rgb.png', 'boatpose'),
#  ('00000074.rgb.png', 'lunge_left'),
#  ('00000075.rgb.png', 'boatpose'),
#  ('00000075.rgb.png', 'boatpose'),
#  ('00000076.rgb.png', 'sideplank_left'),
#  ('00000076.rgb.png', 'squats'),
#  ('00000076.rgb.png', 'situp'),
#  ('00000077.rgb.png', 'sideplank_left'),
#  ('00000078.rgb.png', 'updog'),
#  ('00000078.rgb.png', 'downdog'),
#  ('00000078.rgb.png', 'sideplank_left'),
#  ('00000078.rgb.png', 'lunge_left'),
#  ('00000079.rgb.png', 'situp'),
#  ('00000079.rgb.png', 'legraise'),
#  ('00000079.rgb.png', 'plank'),
#  ('00000080.rgb.png', 'lunge_left'),
#  ('00000080.rgb.png', 'sideplank_right'),
#  ('00000080.rgb.png', 'curls_right'),
#  ('00000080.rgb.png', 'updog'),
#  ('00000081.rgb.png', 'warrior2_left'),
#  ('00000081.rgb.png', 'warrior2_left'),
#  ('00000081.rgb.png', 'legraise'),
#  ('00000082.rgb.png', 'plank'),
#  ('00000082.rgb.png', 'situp'),
#  ('00000082.rgb.png', 'curls_left'),
#  ('00000082.rgb.png', 'lunge_right'),
#  ('00000083.rgb.png', 'boatpose'),
#  ('00000083.rgb.png', 'situp'),
#  ('00000083.rgb.png', 'sideplank_left'),
#  ('00000084.rgb.png', 'jumpingjacks'),
#  ('00000084.rgb.png', 'downdog'),
#  ('00000084.rgb.png', 'pushups'),
#  ('00000084.rgb.png', 'warrior2_right'),
#  ('00000085.rgb.png', 'jumpingjacks'),
#  ('00000085.rgb.png', 'pushups'),
#  ('00000086.rgb.png', 'jumpingjacks'),
#  ('00000087.rgb.png', 'situp'),
#  ('00000087.rgb.png', 'squats'),
#  ('00000087.rgb.png', 'sideplank_right'),
#  ('00000087.rgb.png', 'boatpose'),
#  ('00000088.rgb.png', 'tree_left'),
#  ('00000088.rgb.png', 'hipbridge'),
#  ('00000088.rgb.png', 'plank'),
#  ('00000089.rgb.png', 'lunge_right'),
#  ('00000089.rgb.png', 'tree_right'),
#  ('00000090.rgb.png', 'hipbridge'),
#  ('00000090.rgb.png', 'sideplank_left'),
#  ('00000090.rgb.png', 'downdog'),
#  ('00000091.rgb.png', 'updog'),
#  ('00000091.rgb.png', 'pushups'),
#  ('00000091.rgb.png', 'pushups'),
#  ('00000092.rgb.png', 'plank'),
#  ('00000092.rgb.png', 'legraise'),
#  ('00000092.rgb.png', 'lunge_left'),
#  ('00000092.rgb.png', 'downdog'),
#  ('00000092.rgb.png', 'legraise'),
#  ('00000093.rgb.png', 'pushups'),
#  ('00000093.rgb.png', 'updog'),
#  ('00000093.rgb.png', 'legraise'),
#  ('00000093.rgb.png', 'boatpose'),
#  ('00000094.rgb.png', 'jumpingjacks'),
#  ('00000094.rgb.png', 'tree_left'),
#  ('00000094.rgb.png', 'situp'),
#  ('00000094.rgb.png', 'hipbridge'),
#  ('00000095.rgb.png', 'jumpingjacks'),
#  ('00000095.rgb.png', 'jumpingjacks'),
#  ('00000095.rgb.png', 'plank'),
#  ('00000095.rgb.png', 'downdog'),
#  ('00000096.rgb.png', 'pushups'),
#  ('00000096.rgb.png', 'pushups'),
#  ('00000096.rgb.png', 'squats'),
#  ('00000097.rgb.png', 'hipbridge'),
#  ('00000098.rgb.png', 'curls_right'),
#  ('00000098.rgb.png', 'lunge_right'),
#  ('00000098.rgb.png', 'hipbridge'),
#  ('00000099.rgb.png', 'situp'),
#  ('00000100.rgb.png', 'downdog'),
#  ('00000100.rgb.png', 'curls_both'),
#  ('00000101.rgb.png', 'pushups'),
#  ('00000101.rgb.png', 'updog'),
#  ('00000101.rgb.png', 'downdog'),
#  ('00000101.rgb.png', 'legraise'),
#  ('00000102.rgb.png', 'warrior2_left'),
#  ('00000102.rgb.png', 'lunge_left'),
#  ('00000103.rgb.png', 'lunge_right'),
#  ('00000104.rgb.png', 'squats'),
#  ('00000104.rgb.png', 'updog'),
#  ('00000104.rgb.png', 'lunge_left'),
#  ('00000105.rgb.png', 'jumpingjacks'),
#  ('00000105.rgb.png', 'legraise'),
#  ('00000106.rgb.png', 'lunge_left'),
#  ('00000106.rgb.png', 'plank'),
#  ('00000106.rgb.png', 'boatpose'),
#  ('00000106.rgb.png', 'downdog'),
#  ('00000107.rgb.png', 'downdog'),
#  ('00000107.rgb.png', 'squats'),
#  ('00000107.rgb.png', 'situp'),
#  ('00000108.rgb.png', 'situp'),
#  ('00000108.rgb.png', 'warrior2_left'),
#  ('00000108.rgb.png', 'warrior2_right'),
#  ('00000108.rgb.png', 'lunge_right'),
#  ('00000109.rgb.png', 'curls_both'),
#  ('00000109.rgb.png', 'hipbridge'),
#  ('00000109.rgb.png', 'sideplank_right'),
#  ('00000110.rgb.png', 'hipbridge'),
#  ('00000110.rgb.png', 'curls_both'),
#  ('00000110.rgb.png', 'situp'),
#  ('00000110.rgb.png', 'boatpose'),
#  ('00000111.rgb.png', 'tree_right'),
#  ('00000111.rgb.png', 'tree_left'),
#  ('00000111.rgb.png', 'updog'),
#  ('00000111.rgb.png', 'pushups'),
#  ('00000111.rgb.png', 'situp'),
#  ('00000112.rgb.png', 'tree_right'),
#  ('00000112.rgb.png', 'updog'),
#  ('00000112.rgb.png', 'pushups'),
#  ('00000113.rgb.png', 'warrior2_right'),
#  ('00000113.rgb.png', 'sideplank_left'),
#  ('00000113.rgb.png', 'lunge_right'),
#  ('00000114.rgb.png', 'jumpingjacks'),
#  ('00000114.rgb.png', 'legraise'),
#  ('00000115.rgb.png', 'hipbridge'),
#  ('00000115.rgb.png', 'updog'),
#  ('00000115.rgb.png', 'updog'),
#  ('00000116.rgb.png', 'lunge_right'),
#  ('00000116.rgb.png', 'pushups'),
#  ('00000117.rgb.png', 'boatpose'),
#  ('00000117.rgb.png', 'hipbridge'),
#  ('00000117.rgb.png', 'sideplank_right'),
#  ('00000117.rgb.png', 'updog'),
#  ('00000117.rgb.png', 'pushups'),
#  ('00000118.rgb.png', 'warrior2_left'),
#  ('00000118.rgb.png', 'hipbridge'),
#  ('00000118.rgb.png', 'squats'),
#  ('00000119.rgb.png', 'plank'),
#  ('00000119.rgb.png', 'sideplank_right'),
#  ('00000119.rgb.png', 'downdog'),
#  ('00000120.rgb.png', 'plank'),
#  ('00000120.rgb.png', 'boatpose'),
#  ('00000120.rgb.png', 'boatpose'),
#  ('00000120.rgb.png', 'situp'),
#  ('00000120.rgb.png', 'downdog'),
#  ('00000121.rgb.png', 'lunge_right'),
#  ('00000121.rgb.png', 'plank'),
#  ('00000121.rgb.png', 'tree_right'),
#  ('00000122.rgb.png', 'updog'),
#  ('00000123.rgb.png', 'legraise'),
#  ('00000123.rgb.png', 'legraise'),
#  ('00000123.rgb.png', 'warrior2_right'),
#  ('00000124.rgb.png', 'sideplank_right'),
#  ('00000124.rgb.png', 'legraise'),
#  ('00000124.rgb.png', 'updog'),
#  ('00000125.rgb.png', 'squats'),
#  ('00000125.rgb.png', 'plank'),
#  ('00000125.rgb.png', 'warrior2_right'),
#  ('00000125.rgb.png', 'pushups'),
#  ('00000126.rgb.png', 'lunge_right'),
#  ('00000126.rgb.png', 'situp'),
#  ('00000126.rgb.png', 'tree_right'),
#  ('00000127.rgb.png', 'legraise'),
#  ('00000127.rgb.png', 'boatpose'),
#  ('00000127.rgb.png', 'warrior2_left'),
#  ('00000127.rgb.png', 'warrior2_left'),
#  ('00000128.rgb.png', 'downdog'),
#  ('00000128.rgb.png', 'curls_both'),
#  ('00000129.rgb.png', 'legraise'),
#  ('00000130.rgb.png', 'updog'),
#  ('00000130.rgb.png', 'updog'),
#  ('00000130.rgb.png', 'jumpingjacks'),
#  ('00000130.rgb.png', 'legraise'),
#  ('00000130.rgb.png', 'pushups'),
#  ('00000131.rgb.png', 'downdog'),
#  ('00000131.rgb.png', 'pushups'),
#  ('00000132.rgb.png', 'plank'),
#  ('00000132.rgb.png', 'jumpingjacks'),
#  ('00000132.rgb.png', 'hipbridge'),
#  ('00000133.rgb.png', 'sideplank_right'),
#  ('00000133.rgb.png', 'plank'),
#  ('00000133.rgb.png', 'legraise'),
#  ('00000134.rgb.png', 'pushups'),
#  ('00000135.rgb.png', 'warrior2_right'),
#  ('00000136.rgb.png', 'plank'),
#  ('00000136.rgb.png', 'boatpose'),
#  ('00000137.rgb.png', 'hipbridge'),
#  ('00000137.rgb.png', 'downdog'),
#  ('00000137.rgb.png', 'squats'),
#  ('00000137.rgb.png', 'sideplank_right'),
#  ('00000138.rgb.png', 'plank'),
#  ('00000138.rgb.png', 'lunge_left'),
#  ('00000139.rgb.png', 'updog'),
#  ('00000139.rgb.png', 'tree_left'),
#  ('00000139.rgb.png', 'situp'),
#  ('00000139.rgb.png', 'updog'),
#  ('00000139.rgb.png', 'curls_left'),
#  ('00000140.rgb.png', 'squats'),
#  ('00000140.rgb.png', 'plank'),
#  ('00000140.rgb.png', 'plank'),
#  ('00000140.rgb.png', 'curls_left'),
#  ('00000140.rgb.png', 'sideplank_right'),
#  ('00000141.rgb.png', 'tree_right'),
#  ('00000141.rgb.png', 'tree_left'),
#  ('00000141.rgb.png', 'curls_right'),
#  ('00000142.rgb.png', 'updog'),
#  ('00000142.rgb.png', 'downdog'),
#  ('00000142.rgb.png', 'curls_right'),
#  ('00000143.rgb.png', 'hipbridge'),
#  ('00000144.rgb.png', 'sideplank_right'),
#  ('00000144.rgb.png', 'boatpose'),
#  ('00000145.rgb.png', 'situp'),
#  ('00000145.rgb.png', 'updog'),
#  ('00000145.rgb.png', 'jumpingjacks'),
#  ('00000145.rgb.png', 'plank'),
#  ('00000146.rgb.png', 'jumpingjacks'),
#  ('00000146.rgb.png', 'sideplank_left'),
#  ('00000147.rgb.png', 'legraise'),
#  ('00000147.rgb.png', 'squats'),
#  ('00000148.rgb.png', 'plank'),
#  ('00000148.rgb.png', 'warrior2_left'),
#  ('00000149.rgb.png', 'updog'),
#  ('00000150.rgb.png', 'downdog'),
#  ('00000150.rgb.png', 'squats'),
#  ('00000151.rgb.png', 'updog'),
#  ('00000151.rgb.png', 'legraise'),
#  ('00000151.rgb.png', 'legraise'),
#  ('00000152.rgb.png', 'jumpingjacks'),
#  ('00000152.rgb.png', 'curls_right'),
#  ('00000152.rgb.png', 'warrior2_right'),
#  ('00000152.rgb.png', 'curls_left'),
#  ('00000152.rgb.png', 'updog'),
#  ('00000153.rgb.png', 'updog'),
#  ('00000153.rgb.png', 'downdog'),
#  ('00000153.rgb.png', 'hipbridge'),
#  ('00000153.rgb.png', 'squats'),
#  ('00000154.rgb.png', 'situp'),
#  ('00000154.rgb.png', 'updog'),
#  ('00000154.rgb.png', 'plank'),
#  ('00000155.rgb.png', 'jumpingjacks'),
#  ('00000155.rgb.png', 'situp'),
#  ('00000155.rgb.png', 'sideplank_left'),
#  ('00000156.rgb.png', 'tree_right'),
#  ('00000156.rgb.png', 'tree_left'),
#  ('00000156.rgb.png', 'lunge_left'),
#  ('00000156.rgb.png', 'situp'),
#  ('00000157.rgb.png', 'boatpose'),
#  ('00000157.rgb.png', 'downdog'),
#  ('00000157.rgb.png', 'updog'),
#  ('00000158.rgb.png', 'situp'),
#  ('00000159.rgb.png', 'warrior2_right'),
#  ('00000159.rgb.png', 'plank'),
#  ('00000159.rgb.png', 'pushups'),
#  ('00000160.rgb.png', 'situp'),
#  ('00000160.rgb.png', 'updog'),
#  ('00000160.rgb.png', 'hipbridge'),
#  ('00000160.rgb.png', 'jumpingjacks'),
#  ('00000161.rgb.png', 'boatpose'),
#  ('00000161.rgb.png', 'situp'),
#  ('00000161.rgb.png', 'legraise'),
#  ('00000162.rgb.png', 'updog'),
#  ('00000162.rgb.png', 'lunge_right'),
#  ('00000162.rgb.png', 'curls_both'),
#  ('00000162.rgb.png', 'legraise'),
#  ('00000162.rgb.png', 'legraise'),
#  ('00000163.rgb.png', 'hipbridge'),
#  ('00000163.rgb.png', 'squats'),
#  ('00000163.rgb.png', 'curls_both'),
#  ('00000163.rgb.png', 'tree_right'),
#  ('00000164.rgb.png', 'downdog'),
#  ('00000164.rgb.png', 'situp'),
#  ('00000165.rgb.png', 'boatpose'),
#  ('00000165.rgb.png', 'situp'),
#  ('00000165.rgb.png', 'curls_both'),
#  ('00000165.rgb.png', 'lunge_right'),
#  ('00000165.rgb.png', 'lunge_left'),
#  ('00000166.rgb.png', 'curls_right'),
#  ('00000166.rgb.png', 'sideplank_left'),
#  ('00000166.rgb.png', 'hipbridge'),
#  ('00000167.rgb.png', 'boatpose'),
#  ('00000167.rgb.png', 'sideplank_right'),
#  ('00000168.rgb.png', 'legraise'),
#  ('00000168.rgb.png', 'downdog'),
#  ('00000169.rgb.png', 'boatpose'),
#  ('00000169.rgb.png', 'tree_right'),
#  ('00000170.rgb.png', 'sideplank_left'),
#  ('00000170.rgb.png', 'squats'),
#  ('00000170.rgb.png', 'boatpose'),
#  ('00000170.rgb.png', 'updog'),
#  ('00000171.rgb.png', 'downdog'),
#  ('00000171.rgb.png', 'updog'),
#  ('00000171.rgb.png', 'legraise'),
#  ('00000172.rgb.png', 'downdog'),
#  ('00000172.rgb.png', 'warrior2_left'),
#  ('00000172.rgb.png', 'pushups'),
#  ('00000172.rgb.png', 'plank'),
#  ('00000172.rgb.png', 'squats'),
#  ('00000173.rgb.png', 'boatpose'),
#  ('00000173.rgb.png', 'tree_right'),
#  ('00000173.rgb.png', 'plank'),
#  ('00000173.rgb.png', 'squats'),
#  ('00000173.rgb.png', 'pushups'),
#  ('00000174.rgb.png', 'lunge_right'),
#  ('00000174.rgb.png', 'downdog'),
#  ('00000175.rgb.png', 'legraise'),
#  ('00000175.rgb.png', 'curls_right'),
#  ('00000175.rgb.png', 'tree_right'),
#  ('00000176.rgb.png', 'legraise'),
#  ('00000176.rgb.png', 'updog'),
#  ('00000176.rgb.png', 'legraise'),
#  ('00000176.rgb.png', 'tree_left'),
#  ('00000176.rgb.png', 'pushups'),
#  ('00000177.rgb.png', 'plank'),
#  ('00000177.rgb.png', 'pushups'),
#  ('00000177.rgb.png', 'curls_both'),
#  ('00000177.rgb.png', 'legraise'),
#  ('00000178.rgb.png', 'boatpose'),
#  ('00000178.rgb.png', 'updog'),
#  ('00000178.rgb.png', 'updog'),
#  ('00000179.rgb.png', 'squats'),
#  ('00000179.rgb.png', 'boatpose'),
#  ('00000179.rgb.png', 'warrior2_right'),
#  ('00000180.rgb.png', 'tree_left'),
#  ('00000180.rgb.png', 'jumpingjacks'),
#  ('00000180.rgb.png', 'hipbridge'),
#  ('00000181.rgb.png', 'boatpose'),
#  ('00000181.rgb.png', 'curls_left'),
#  ('00000181.rgb.png', 'situp'),
#  ('00000182.rgb.png', 'curls_both'),
#  ('00000182.rgb.png', 'plank'),
#  ('00000182.rgb.png', 'tree_left'),
#  ('00000182.rgb.png', 'sideplank_left'),
#  ('00000182.rgb.png', 'jumpingjacks'),
#  ('00000183.rgb.png', 'situp'),
#  ('00000183.rgb.png', 'curls_both'),
#  ('00000184.rgb.png', 'lunge_right'),
#  ('00000184.rgb.png', 'sideplank_right'),
#  ('00000184.rgb.png', 'tree_right'),
#  ('00000184.rgb.png', 'warrior2_left'),
#  ('00000185.rgb.png', 'plank'),
#  ('00000185.rgb.png', 'tree_right'),
#  ('00000185.rgb.png', 'sideplank_left'),
#  ('00000186.rgb.png', 'warrior2_right'),
#  ('00000186.rgb.png', 'tree_right'),
#  ('00000186.rgb.png', 'squats'),
#  ('00000186.rgb.png', 'boatpose'),
#  ('00000186.rgb.png', 'jumpingjacks'),
#  ('00000187.rgb.png', 'tree_left'),
#  ('00000187.rgb.png', 'boatpose'),
#  ('00000187.rgb.png', 'downdog'),
#  ('00000188.rgb.png', 'situp'),
#  ('00000188.rgb.png', 'plank'),
#  ('00000188.rgb.png', 'situp'),
#  ('00000188.rgb.png', 'lunge_right'),
#  ('00000189.rgb.png', 'situp'),
#  ('00000189.rgb.png', 'boatpose'),
#  ('00000189.rgb.png', 'downdog'),
#  ('00000189.rgb.png', 'situp'),
#  ('00000190.rgb.png', 'curls_both'),
#  ('00000190.rgb.png', 'downdog'),
#  ('00000190.rgb.png', 'legraise'),
#  ('00000190.rgb.png', 'updog'),
#  ('00000190.rgb.png', 'sideplank_right'),
#  ('00000191.rgb.png', 'lunge_left'),
#  ('00000191.rgb.png', 'boatpose'),
#  ('00000191.rgb.png', 'downdog'),
#  ('00000191.rgb.png', 'sideplank_right'),
#  ('00000191.rgb.png', 'curls_both'),
#  ('00000192.rgb.png', 'jumpingjacks'),
#  ('00000192.rgb.png', 'warrior2_right'),
#  ('00000192.rgb.png', 'updog'),
#  ('00000192.rgb.png', 'updog'),
#  ('00000192.rgb.png', 'hipbridge'),
#  ('00000193.rgb.png', 'curls_right'),
#  ('00000194.rgb.png', 'sideplank_left'),
#  ('00000194.rgb.png', 'sideplank_left'),
#  ('00000195.rgb.png', 'squats'),
#  ('00000195.rgb.png', 'jumpingjacks'),
#  ('00000195.rgb.png', 'boatpose'),
#  ('00000195.rgb.png', 'jumpingjacks'),
#  ('00000196.rgb.png', 'curls_right'),
#  ('00000196.rgb.png', 'sideplank_left'),
#  ('00000196.rgb.png', 'legraise'),
#  ('00000196.rgb.png', 'warrior2_right'),
#  ('00000196.rgb.png', 'boatpose'),
#  ('00000197.rgb.png', 'pushups'),
#  ('00000198.rgb.png', 'legraise'),
#  ('00000198.rgb.png', 'jumpingjacks'),
#  ('00000198.rgb.png', 'situp'),
#  ('00000198.rgb.png', 'boatpose'),
#  ('00000199.rgb.png', 'updog'),
#  ('00000199.rgb.png', 'legraise'),
#  ('00000199.rgb.png', 'lunge_right'),
#  ('00000199.rgb.png', 'squats'),
#  ('00000200.rgb.png', 'updog'),
#  ('00000200.rgb.png', 'legraise'),
#  ('00000201.rgb.png', 'plank'),
#  ('00000201.rgb.png', 'sideplank_left'),
#  ('00000201.rgb.png', 'hipbridge'),
#  ('00000202.rgb.png', 'lunge_left'),
#  ('00000202.rgb.png', 'updog'),
#  ('00000203.rgb.png', 'curls_both'),
#  ('00000203.rgb.png', 'lunge_right'),
#  ('00000203.rgb.png', 'curls_left'),
#  ('00000204.rgb.png', 'boatpose'),
#  ('00000204.rgb.png', 'jumpingjacks'),
#  ('00000204.rgb.png', 'updog'),
#  ('00000204.rgb.png', 'warrior2_left'),
#  ('00000205.rgb.png', 'plank'),
#  ('00000205.rgb.png', 'downdog'),
#  ('00000205.rgb.png', 'pushups'),
#  ('00000205.rgb.png', 'hipbridge'),
#  ('00000205.rgb.png', 'legraise'),
#  ('00000206.rgb.png', 'tree_right'),
#  ('00000206.rgb.png', 'boatpose'),
#  ('00000206.rgb.png', 'boatpose'),
#  ('00000207.rgb.png', 'boatpose'),
#  ('00000207.rgb.png', 'jumpingjacks'),
#  ('00000207.rgb.png', 'warrior2_right'),
#  ('00000208.rgb.png', 'boatpose'),
#  ('00000208.rgb.png', 'pushups'),
#  ('00000208.rgb.png', 'downdog'),
#  ('00000208.rgb.png', 'legraise'),
#  ('00000209.rgb.png', 'lunge_left'),
#  ('00000209.rgb.png', 'updog'),
#  ('00000209.rgb.png', 'hipbridge'),
#  ('00000210.rgb.png', 'tree_right'),
#  ('00000210.rgb.png', 'hipbridge'),
#  ('00000210.rgb.png', 'updog'),
#  ('00000210.rgb.png', 'downdog'),
#  ('00000211.rgb.png', 'pushups'),
#  ('00000211.rgb.png', 'plank'),
#  ('00000211.rgb.png', 'plank'),
#  ('00000211.rgb.png', 'legraise'),
#  ('00000212.rgb.png', 'curls_left'),
#  ('00000212.rgb.png', 'boatpose'),
#  ('00000212.rgb.png', 'tree_left'),
#  ('00000212.rgb.png', 'downdog'),
#  ('00000213.rgb.png', 'sideplank_left'),
#  ('00000213.rgb.png', 'curls_both'),
#  ('00000213.rgb.png', 'tree_right'),
#  ('00000214.rgb.png', 'boatpose'),
#  ('00000214.rgb.png', 'updog'),
#  ('00000214.rgb.png', 'sideplank_left'),
#  ('00000214.rgb.png', 'tree_left'),
#  ('00000215.rgb.png', 'boatpose'),
#  ('00000215.rgb.png', 'lunge_right'),
#  ('00000215.rgb.png', 'warrior2_left'),
#  ('00000216.rgb.png', 'curls_left'),
#  ('00000216.rgb.png', 'jumpingjacks'),
#  ('00000216.rgb.png', 'hipbridge'),
#  ('00000217.rgb.png', 'situp'),
#  ('00000217.rgb.png', 'pushups'),
#  ('00000217.rgb.png', 'sideplank_right'),
#  ('00000217.rgb.png', 'sideplank_left'),
#  ('00000218.rgb.png', 'warrior2_left'),
#  ('00000218.rgb.png', 'jumpingjacks'),
#  ('00000219.rgb.png', 'jumpingjacks'),
#  ('00000219.rgb.png', 'curls_right'),
#  ('00000219.rgb.png', 'curls_right'),
#  ('00000220.rgb.png', 'curls_right'),
#  ('00000220.rgb.png', 'hipbridge'),
#  ('00000220.rgb.png', 'updog'),
#  ('00000220.rgb.png', 'curls_left'),
#  ('00000221.rgb.png', 'hipbridge'),
#  ('00000221.rgb.png', 'lunge_left'),
#  ('00000222.rgb.png', 'sideplank_right'),
#  ('00000222.rgb.png', 'tree_right'),
#  ('00000223.rgb.png', 'updog'),
#  ('00000223.rgb.png', 'lunge_left'),
#  ('00000223.rgb.png', 'sideplank_left'),
#  ('00000223.rgb.png', 'plank'),
#  ('00000224.rgb.png', 'legraise'),
#  ('00000224.rgb.png', 'legraise'),
#  ('00000224.rgb.png', 'boatpose'),
#  ('00000225.rgb.png', 'tree_right'),
#  ('00000225.rgb.png', 'boatpose'),
#  ('00000226.rgb.png', 'hipbridge'),
#  ('00000226.rgb.png', 'hipbridge'),
#  ('00000226.rgb.png', 'boatpose'),
#  ('00000226.rgb.png', 'jumpingjacks'),
#  ('00000226.rgb.png', 'legraise'),
#  ('00000227.rgb.png', 'jumpingjacks'),
#  ('00000227.rgb.png', 'sideplank_right'),
#  ('00000227.rgb.png', 'plank'),
#  ('00000228.rgb.png', 'plank'),
#  ('00000228.rgb.png', 'downdog'),
#  ('00000228.rgb.png', 'situp'),
#  ('00000228.rgb.png', 'pushups'),
#  ('00000229.rgb.png', 'curls_left'),
#  ('00000229.rgb.png', 'tree_left'),
#  ('00000230.rgb.png', 'lunge_right'),
#  ('00000231.rgb.png', 'tree_right'),
#  ('00000231.rgb.png', 'jumpingjacks'),
#  ('00000231.rgb.png', 'updog'),
#  ('00000232.rgb.png', 'tree_left'),
#  ('00000233.rgb.png', 'updog'),
#  ('00000234.rgb.png', 'boatpose'),
#  ('00000234.rgb.png', 'sideplank_left'),
#  ('00000234.rgb.png', 'warrior2_left'),
#  ('00000234.rgb.png', 'updog'),
#  ('00000235.rgb.png', 'situp'),
#  ('00000235.rgb.png', 'lunge_left'),
#  ('00000235.rgb.png', 'downdog'),
#  ('00000235.rgb.png', 'hipbridge'),
#  ('00000235.rgb.png', 'boatpose'),
#  ('00000236.rgb.png', 'plank'),
#  ('00000237.rgb.png', 'boatpose'),
#  ('00000237.rgb.png', 'squats'),
#  ('00000238.rgb.png', 'lunge_right'),
#  ('00000238.rgb.png', 'hipbridge'),
#  ('00000238.rgb.png', 'pushups'),
#  ('00000238.rgb.png', 'tree_right'),
#  ('00000239.rgb.png', 'curls_both'),
#  ('00000240.rgb.png', 'updog'),
#  ('00000240.rgb.png', 'warrior2_left'),
#  ('00000241.rgb.png', 'legraise'),
#  ('00000241.rgb.png', 'boatpose'),
#  ('00000241.rgb.png', 'lunge_left'),
#  ('00000242.rgb.png', 'pushups'),
#  ('00000242.rgb.png', 'squats'),
#  ('00000243.rgb.png', 'pushups'),
#  ('00000244.rgb.png', 'downdog'),
#  ('00000244.rgb.png', 'squats'),
#  ('00000245.rgb.png', 'sideplank_right'),
#  ('00000245.rgb.png', 'legraise'),
#  ('00000245.rgb.png', 'legraise'),
#  ('00000246.rgb.png', 'updog'),
#  ('00000246.rgb.png', 'plank'),
#  ('00000246.rgb.png', 'lunge_left'),
#  ('00000247.rgb.png', 'lunge_right'),
#  ('00000247.rgb.png', 'pushups'),
#  ('00000248.rgb.png', 'warrior2_right'),
#  ('00000248.rgb.png', 'tree_left'),
#  ('00000249.rgb.png', 'jumpingjacks'),
#  ('00000250.rgb.png', 'downdog'),
#  ('00000250.rgb.png', 'boatpose'),
#  ('00000250.rgb.png', 'updog'),
#  ('00000250.rgb.png', 'downdog'),
#  ('00000250.rgb.png', 'warrior2_left'),
#  ('00000251.rgb.png', 'situp'),
#  ('00000252.rgb.png', 'updog'),
#  ('00000252.rgb.png', 'jumpingjacks'),
#  ('00000252.rgb.png', 'plank'),
#  ('00000253.rgb.png', 'curls_left'),
#  ('00000253.rgb.png', 'tree_left'),
#  ('00000254.rgb.png', 'curls_right'),
#  ('00000254.rgb.png', 'lunge_right'),
#  ('00000255.rgb.png', 'updog'),
#  ('00000255.rgb.png', 'plank'),
#  ('00000255.rgb.png', 'jumpingjacks'),
#  ('00000256.rgb.png', 'curls_left'),
#  ('00000256.rgb.png', 'boatpose'),
#  ('00000256.rgb.png', 'squats'),
#  ('00000257.rgb.png', 'curls_right'),
#  ('00000257.rgb.png', 'boatpose'),
#  ('00000258.rgb.png', 'boatpose'),
#  ('00000258.rgb.png', 'sideplank_right'),
#  ('00000258.rgb.png', 'sideplank_left'),
#  ('00000258.rgb.png', 'pushups'),
#  ('00000259.rgb.png', 'downdog'),
#  ('00000259.rgb.png', 'boatpose'),
#  ('00000259.rgb.png', 'updog'),
#  ('00000260.rgb.png', 'hipbridge'),
#  ('00000260.rgb.png', 'pushups'),
#  ('00000261.rgb.png', 'hipbridge'),
#  ('00000262.rgb.png', 'tree_right'),
#  ('00000262.rgb.png', 'hipbridge'),
#  ('00000263.rgb.png', 'curls_left'),
#  ('00000263.rgb.png', 'curls_left'),
#  ('00000263.rgb.png', 'lunge_right'),
#  ('00000264.rgb.png', 'boatpose'),
#  ('00000264.rgb.png', 'situp'),
#  ('00000264.rgb.png', 'situp'),
#  ('00000264.rgb.png', 'tree_left'),
#  ('00000265.rgb.png', 'legraise'),
#  ('00000265.rgb.png', 'curls_left'),
#  ('00000265.rgb.png', 'plank'),
#  ('00000266.rgb.png', 'pushups'),
#  ('00000267.rgb.png', 'lunge_right'),
#  ('00000267.rgb.png', 'boatpose'),
#  ('00000268.rgb.png', 'legraise'),
#  ('00000269.rgb.png', 'curls_both'),
#  ('00000269.rgb.png', 'lunge_left'),
#  ('00000270.rgb.png', 'curls_right'),
#  ('00000270.rgb.png', 'plank'),
#  ('00000270.rgb.png', 'pushups'),
#  ('00000271.rgb.png', 'jumpingjacks'),
#  ('00000272.rgb.png', 'hipbridge'),
#  ('00000272.rgb.png', 'updog'),
#  ('00000273.rgb.png', 'warrior2_right'),
#  ('00000274.rgb.png', 'legraise'),
#  ('00000275.rgb.png', 'downdog'),
#  ('00000275.rgb.png', 'situp'),
#  ('00000275.rgb.png', 'sideplank_right'),
#  ('00000275.rgb.png', 'pushups'),
#  ('00000276.rgb.png', 'legraise'),
#  ('00000277.rgb.png', 'situp'),
#  ('00000277.rgb.png', 'tree_right'),
#  ('00000277.rgb.png', 'legraise'),
#  ('00000277.rgb.png', 'updog'),
#  ('00000277.rgb.png', 'boatpose'),
#  ('00000278.rgb.png', 'updog'),
#  ('00000278.rgb.png', 'updog'),
#  ('00000278.rgb.png', 'plank'),
#  ('00000278.rgb.png', 'pushups'),
#  ('00000279.rgb.png', 'curls_right'),
#  ('00000280.rgb.png', 'legraise'),
#  ('00000280.rgb.png', 'tree_left'),
#  ('00000281.rgb.png', 'downdog'),
#  ('00000281.rgb.png', 'downdog'),
#  ('00000281.rgb.png', 'curls_left'),
#  ('00000281.rgb.png', 'tree_right'),
#  ('00000282.rgb.png', 'tree_right'),
#  ('00000282.rgb.png', 'curls_both'),
#  ('00000282.rgb.png', 'updog'),
#  ('00000283.rgb.png', 'hipbridge'),
#  ('00000283.rgb.png', 'curls_right'),
#  ('00000283.rgb.png', 'tree_right'),
#  ('00000284.rgb.png', 'curls_both'),
#  ('00000284.rgb.png', 'squats'),
#  ('00000285.rgb.png', 'legraise'),
#  ('00000285.rgb.png', 'squats'),
#  ('00000285.rgb.png', 'hipbridge'),
#  ('00000285.rgb.png', 'situp'),
#  ('00000286.rgb.png', 'squats'),
#  ('00000286.rgb.png', 'legraise'),
#  ('00000286.rgb.png', 'updog'),
#  ('00000286.rgb.png', 'warrior2_left'),
#  ('00000287.rgb.png', 'tree_right'),
#  ('00000288.rgb.png', 'squats'),
#  ('00000288.rgb.png', 'situp'),
#  ('00000289.rgb.png', 'situp'),
#  ('00000290.rgb.png', 'hipbridge'),
#  ('00000290.rgb.png', 'hipbridge'),
#  ('00000290.rgb.png', 'sideplank_left'),
#  ('00000291.rgb.png', 'situp'),
#  ('00000291.rgb.png', 'hipbridge'),
#  ('00000292.rgb.png', 'sideplank_left'),
#  ('00000293.rgb.png', 'boatpose'),
#  ('00000293.rgb.png', 'curls_right'),
#  ('00000293.rgb.png', 'updog'),
#  ('00000293.rgb.png', 'updog'),
#  ('00000293.rgb.png', 'sideplank_left'),
#  ('00000294.rgb.png', 'pushups'),
#  ('00000294.rgb.png', 'warrior2_right'),
#  ('00000294.rgb.png', 'jumpingjacks'),
#  ('00000294.rgb.png', 'sideplank_left'),
#  ('00000295.rgb.png', 'hipbridge'),
#  ('00000295.rgb.png', 'pushups'),
#  ('00000295.rgb.png', 'hipbridge'),
#  ('00000296.rgb.png', 'situp'),
#  ('00000296.rgb.png', 'hipbridge'),
#  ('00000296.rgb.png', 'legraise'),
#  ('00000296.rgb.png', 'warrior2_left'),
#  ('00000297.rgb.png', 'legraise'),
#  ('00000297.rgb.png', 'pushups'),
#  ('00000297.rgb.png', 'tree_left'),
#  ('00000297.rgb.png', 'curls_right'),
#  ('00000298.rgb.png', 'situp'),
#  ('00000298.rgb.png', 'squats'),
#  ('00000298.rgb.png', 'sideplank_left'),
#  ('00000298.rgb.png', 'downdog'),
#  ('00000298.rgb.png', 'downdog'),
#  ('00000299.rgb.png', 'plank'),
#  ('00000299.rgb.png', 'lunge_left'),
#  ('00000300.rgb.png', 'updog'),
#  ('00000300.rgb.png', 'hipbridge'),
#  ('00000300.rgb.png', 'legraise'),
#  ('00000301.rgb.png', 'squats'),
#  ('00000301.rgb.png', 'tree_left'),
#  ('00000301.rgb.png', 'tree_left'),
#  ('00000302.rgb.png', 'jumpingjacks'),
#  ('00000302.rgb.png', 'situp'),
#  ('00000302.rgb.png', 'pushups'),
#  ('00000302.rgb.png', 'lunge_left'),
#  ('00000303.rgb.png', 'pushups'),
#  ('00000303.rgb.png', 'legraise'),
#  ('00000303.rgb.png', 'lunge_right'),
#  ('00000304.rgb.png', 'squats'),
#  ('00000304.rgb.png', 'hipbridge'),
#  ('00000304.rgb.png', 'warrior2_left'),
#  ('00000304.rgb.png', 'boatpose'),
#  ('00000305.rgb.png', 'hipbridge'),
#  ('00000305.rgb.png', 'boatpose'),
#  ('00000305.rgb.png', 'tree_left'),
#  ('00000306.rgb.png', 'squats'),
#  ('00000307.rgb.png', 'warrior2_right'),
#  ('00000307.rgb.png', 'legraise'),
#  ('00000308.rgb.png', 'jumpingjacks'),
#  ('00000308.rgb.png', 'curls_right'),
#  ('00000308.rgb.png', 'warrior2_right'),
#  ('00000308.rgb.png', 'warrior2_left'),
#  ('00000308.rgb.png', 'tree_left'),
#  ('00000309.rgb.png', 'tree_left'),
#  ('00000310.rgb.png', 'updog'),
#  ('00000311.rgb.png', 'sideplank_right'),
#  ('00000312.rgb.png', 'hipbridge'),
#  ('00000312.rgb.png', 'situp'),
#  ('00000312.rgb.png', 'pushups'),
#  ('00000313.rgb.png', 'lunge_left'),
#  ('00000313.rgb.png', 'pushups'),
#  ('00000314.rgb.png', 'lunge_left'),
#  ('00000314.rgb.png', 'hipbridge'),
#  ('00000314.rgb.png', 'hipbridge'),
#  ('00000315.rgb.png', 'plank'),
#  ('00000315.rgb.png', 'situp'),
#  ('00000316.rgb.png', 'jumpingjacks'),
#  ('00000316.rgb.png', 'warrior2_right'),
#  ('00000316.rgb.png', 'boatpose'),
#  ('00000317.rgb.png', 'situp'),
#  ('00000317.rgb.png', 'lunge_right'),
#  ('00000317.rgb.png', 'updog'),
#  ('00000318.rgb.png', 'squats'),
#  ('00000318.rgb.png', 'plank'),
#  ('00000318.rgb.png', 'downdog'),
#  ('00000319.rgb.png', 'hipbridge'),
#  ('00000319.rgb.png', 'squats'),
#  ('00000319.rgb.png', 'pushups'),
#  ('00000319.rgb.png', 'sideplank_left'),
#  ('00000320.rgb.png', 'legraise'),
#  ('00000320.rgb.png', 'pushups'),
#  ('00000320.rgb.png', 'sideplank_right'),
#  ('00000320.rgb.png', 'lunge_left'),
#  ('00000321.rgb.png', 'lunge_right'),
#  ('00000321.rgb.png', 'sideplank_right'),
#  ('00000321.rgb.png', 'plank'),
#  ('00000321.rgb.png', 'pushups'),
#  ('00000322.rgb.png', 'jumpingjacks'),
#  ('00000323.rgb.png', 'plank'),
#  ('00000324.rgb.png', 'jumpingjacks'),
#  ('00000325.rgb.png', 'lunge_right'),
#  ('00000325.rgb.png', 'sideplank_right'),
#  ('00000325.rgb.png', 'boatpose'),
#  ('00000325.rgb.png', 'lunge_right'),
#  ('00000326.rgb.png', 'sideplank_right'),
#  ('00000327.rgb.png', 'tree_right'),
#  ('00000328.rgb.png', 'hipbridge'),
#  ('00000328.rgb.png', 'situp'),
#  ('00000328.rgb.png', 'pushups'),
#  ('00000329.rgb.png', 'jumpingjacks'),
#  ('00000329.rgb.png', 'legraise'),
#  ('00000329.rgb.png', 'warrior2_right'),
#  ('00000329.rgb.png', 'sideplank_left'),
#  ('00000329.rgb.png', 'updog'),
#  ('00000330.rgb.png', 'legraise'),
#  ('00000330.rgb.png', 'jumpingjacks'),
#  ('00000330.rgb.png', 'lunge_left'),
#  ('00000330.rgb.png', 'jumpingjacks'),
#  ('00000331.rgb.png', 'sideplank_right'),
#  ('00000331.rgb.png', 'pushups'),
#  ('00000331.rgb.png', 'jumpingjacks'),
#  ('00000331.rgb.png', 'plank'),
#  ('00000332.rgb.png', 'squats'),
#  ('00000332.rgb.png', 'jumpingjacks'),
#  ('00000332.rgb.png', 'plank'),
#  ('00000332.rgb.png', 'lunge_right'),
#  ('00000332.rgb.png', 'hipbridge'),
#  ('00000333.rgb.png', 'downdog'),
#  ('00000333.rgb.png', 'downdog'),
#  ('00000333.rgb.png', 'legraise'),
#  ('00000333.rgb.png', 'lunge_right'),
#  ('00000334.rgb.png', 'warrior2_right'),
#  ('00000334.rgb.png', 'curls_left'),
#  ('00000334.rgb.png', 'lunge_right'),
#  ('00000334.rgb.png', 'warrior2_left'),
#  ('00000335.rgb.png', 'hipbridge'),
#  ('00000335.rgb.png', 'sideplank_right'),
#  ('00000335.rgb.png', 'curls_right'),
#  ('00000336.rgb.png', 'tree_right'),
#  ('00000336.rgb.png', 'updog'),
#  ('00000336.rgb.png', 'curls_both'),
#  ('00000336.rgb.png', 'plank'),
#  ('00000337.rgb.png', 'sideplank_left'),
#  ('00000337.rgb.png', 'lunge_right'),
#  ('00000337.rgb.png', 'plank'),
#  ('00000338.rgb.png', 'downdog'),
#  ('00000339.rgb.png', 'situp'),
#  ('00000339.rgb.png', 'sideplank_left'),
#  ('00000339.rgb.png', 'pushups'),
#  ('00000339.rgb.png', 'squats'),
#  ('00000340.rgb.png', 'jumpingjacks'),
#  ('00000340.rgb.png', 'boatpose'),
#  ('00000340.rgb.png', 'plank'),
#  ('00000341.rgb.png', 'legraise'),
#  ('00000341.rgb.png', 'curls_left'),
#  ('00000341.rgb.png', 'plank'),
#  ('00000341.rgb.png', 'tree_right'),
#  ('00000342.rgb.png', 'situp'),
#  ('00000342.rgb.png', 'tree_left'),
#  ('00000342.rgb.png', 'jumpingjacks'),
#  ('00000342.rgb.png', 'tree_right'),
#  ('00000343.rgb.png', 'tree_right'),
#  ('00000344.rgb.png', 'downdog'),
#  ('00000344.rgb.png', 'updog'),
#  ('00000345.rgb.png', 'boatpose'),
#  ('00000345.rgb.png', 'pushups'),
#  ('00000345.rgb.png', 'hipbridge'),
#  ('00000345.rgb.png', 'downdog'),
#  ('00000346.rgb.png', 'warrior2_right'),
#  ...]

# %%
image_arr = np.array(image)
image_arr
# Out:
# array([[[169, 159, 142, 255],
#         [168, 160, 142, 255],
#         [169, 161, 144, 255],
#         ...,
#         [ 86,  80,  75, 255],
#         [ 85,  78,  72, 255],
#         [ 87,  80,  73, 255]],
#
#        [[154, 144, 126, 255],
#         [153, 145, 126, 255],
#         [154, 146, 129, 255],
#         ...,
#         [ 83,  77,  70, 255],
#         [ 89,  83,  76, 255],
#         [ 93,  87,  81, 255]],
#
#        [[138, 127, 107, 255],
#         [137, 128, 108, 255],
#         [135, 126, 107, 255],
#         ...,
#         [ 85,  80,  74, 255],
#         [ 95,  91,  87, 255],
#         [ 99,  94,  91, 255]],
#
#        ...,
#
#        [[149, 137, 117, 255],
#         [147, 136, 115, 255],
#         [146, 135, 115, 255],
#         ...,
#         [136, 124, 104, 255],
#         [135, 123, 103, 255],
#         [134, 122, 102, 255]],
#
#        [[146, 135, 114, 255],
#         [146, 134, 113, 255],
#         [147, 135, 115, 255],
#         ...,
#         [130, 118,  98, 255],
#         [132, 120,  99, 255],
#         [135, 122, 101, 255]],
#
#        [[143, 131, 110, 255],
#         [145, 133, 112, 255],
#         [146, 134, 113, 255],
#         ...,
#         [125, 113,  92, 255],
#         [127, 114,  93, 255],
#         [132, 119,  98, 255]]], dtype=uint8)

# %%
image_arr = image_arr[x_left: y_top, x_right: y_bottom, :]

# %%
image_arr
# Out:
# array([], shape=(0, 0, 4), dtype=uint8)

# %%
import matplotlib.pyplot as plt
from PIL import Image

# %%
def crop_image(file_name, bbox, index):
    image = plt.imread(f'/Users/abou48862/code/kvkirya/pt-ai/raw_data/images_to_crop/{file_name}')
    x0 = int(bbox[0])
    y0 = int(bbox[1])
    width = int(bbox[2])
    height = int(bbox[3])
    wanted_boundaries_array = image[y0:y0+height , x0:x0+width, :]
    fig = plt.figure()
    ax = fig.add_subplot(121)
    im_crop = plt.imshow(image[y0:y0+height , x0:x0+width, :])
    #copied_im = im_crop.copy()
    plt.savefig(f'/Users/abou48862/code/kvkirya/pt-ai/raw_data/cropped_data/{file_name}_{index}_cropped.png')

    return str(file_name) + "_" + str(index) + "_cropped"

# %%
crop_image("00000003.rgb.png", [237, 96, 35, 91], 1)

from PIL import Image

# %%
image = plt.imread('/Users/abou48862/code/kvkirya/pt-ai/raw_data/00/00000003.rgb.png')

# %%
box1 = [237, 96, 35, 91]
x0 = box1[0]
y0 = box1[1]
width = box1[2]
height = box1[3]

# %%
image[y0:y0+height , x0:x0+width, :]
# Out:
# array([[[0.16470589, 0.25490198, 0.24313726, 1.        ],
#         [0.16470589, 0.2627451 , 0.2509804 , 1.        ],
#         [0.16470589, 0.26666668, 0.25490198, 1.        ],
#         ...,
#         [0.16078432, 0.25882354, 0.24705882, 1.        ],
#         [0.15686275, 0.25490198, 0.24313726, 1.        ],
#         [0.16078432, 0.25882354, 0.2509804 , 1.        ]],
#
#        [[0.1764706 , 0.2627451 , 0.2509804 , 1.        ],
#         [0.16862746, 0.26666668, 0.2509804 , 1.        ],
#         [0.16470589, 0.2627451 , 0.2509804 , 1.        ],
#         ...,
#         [0.16078432, 0.25882354, 0.24705882, 1.        ],
#         [0.15686275, 0.2509804 , 0.23921569, 1.        ],
#         [0.16078432, 0.25882354, 0.24705882, 1.        ]],
#
#        [[0.16078432, 0.25882354, 0.24313726, 1.        ],
#         [0.15686275, 0.25882354, 0.24705882, 1.        ],
#         [0.16078432, 0.2627451 , 0.2509804 , 1.        ],
#         ...,
#         [0.15686275, 0.25490198, 0.24705882, 1.        ],
#         [0.14901961, 0.24705882, 0.23921569, 1.        ],
#         [0.15686275, 0.25882354, 0.24705882, 1.        ]],
#
#        ...,
#
#        [[0.49411765, 0.44705883, 0.35686275, 1.        ],
#         [0.49019608, 0.44313726, 0.35686275, 1.        ],
#         [0.49019608, 0.44705883, 0.35686275, 1.        ],
#         ...,
#         [0.36078432, 0.28235295, 0.21176471, 1.        ],
#         [0.39607844, 0.3137255 , 0.23921569, 1.        ],
#         [0.5529412 , 0.45882353, 0.36862746, 1.        ]],
#
#        [[0.56078434, 0.5176471 , 0.42352942, 1.        ],
#         [0.5647059 , 0.5176471 , 0.42352942, 1.        ],
#         [0.53333336, 0.48235294, 0.3882353 , 1.        ],
#         ...,
#         [0.36862746, 0.31764707, 0.23921569, 1.        ],
#         [0.36862746, 0.3137255 , 0.23137255, 1.        ],
#         [0.4509804 , 0.39215687, 0.2901961 , 1.        ]],
#
#        [[0.5686275 , 0.52156866, 0.42745098, 1.        ],
#         [0.5686275 , 0.5176471 , 0.42352942, 1.        ],
#         [0.5568628 , 0.5019608 , 0.40784314, 1.        ],
#         ...,
#         [0.5294118 , 0.4745098 , 0.38039216, 1.        ],
#         [0.5411765 , 0.47843137, 0.3764706 , 1.        ],
#         [0.5529412 , 0.49411765, 0.38431373, 1.        ]]], dtype=float32)

# %%
fig = plt.figure()
ax = fig.add_subplot(121)
ax.imshow(plt.imread('/Users/abou48862/code/kvkirya/pt-ai/raw_data/00/00000003.rgb.png'))

# %%
ax1 = fig.add_subplot(222)
ax1.imshow(image[y0:y0+height , x0:x0+width, :])

# %%
fig

# %% [markdown]
# Applying function to all images

# %%
extension_mask = df_complete.file_name.str.endswith(".rgb.png")

df_complete[extension_mask]
# Out:
#            id         file_name   pose_variation pose_category  \
# 0           1  00000001.rgb.png            situp         situp
# 1           1  00000001.rgb.png            situp         situp
# 2           1  00000001.rgb.png       tree_right          tree
# 3           2  00000002.rgb.png  sideplank_right     sideplank
# 4           2  00000002.rgb.png      curls_right         curls
# ...       ...               ...              ...           ...
# 167939  59577  00059577.rgb.png        hipbridge     hipbridge
# 167940  59578  00059578.rgb.png            plank         plank
# 167941  59578  00059578.rgb.png         legraise      legraise
# 167942  59578  00059578.rgb.png        hipbridge     hipbridge
# 167943  59578  00059578.rgb.png   sideplank_left     sideplank
#
#        exercise_category                                               bbox  \
# 0                 [HIIT]  [439.01, 187.01, 56.98000000000002, 53.9800000...
# 1                 [HIIT]  [142.01, 185.01, 51.98000000000002, 54.9800000...
# 2                 [Yoga]  [302.01, 97.01, 38.98000000000002, 161.9800000...
# 3           [Yoga, HIIT]        [477.01, 113.01, 110.98000000000002, 91.98]
# 4                 [HIIT]  [506.01, 99.01, 97.98000000000002, 239.9800000...
# ...                  ...                                                ...
# 167939      [Yoga, HIIT]  [398.01, 229.01, 126.98000000000002, 67.980000...
# 167940      [Yoga, HIIT]  [249.01, 222.01, 245.98000000000002, 132.98000...
# 167941            [HIIT]  [290.01, 137.01, 71.98000000000002, 73.9800000...
# 167942      [Yoga, HIIT]  [297.01, 201.01, 106.98000000000002, 48.980000...
# 167943      [Yoga, HIIT]  [188.01, 151.01, 89.98000000000002, 85.9800000...
#
#         camera_rotation_deg                       bbox_pascal   index
# 0                 78.472965  [439.01, 187.01, 495.99, 240.99]       1
# 1                 78.472965  [142.01, 185.01, 193.99, 239.99]       2
# 2                 78.472965   [302.01, 97.01, 340.99, 258.99]       3
# 3                 67.888454  [477.01, 113.01, 587.99, 204.99]       4
# 4                 67.888454   [506.01, 99.01, 603.99, 338.99]       5
# ...                     ...                               ...     ...
# 167939            70.161267  [398.01, 229.01, 524.99, 296.99]  167940
# 167940            78.559729  [249.01, 222.01, 494.99, 354.99]  167941
# 167941            78.559729  [290.01, 137.01, 361.99, 210.99]  167942
# 167942            78.559729  [297.01, 201.01, 403.99, 249.99]  167943
# 167943            78.559729  [188.01, 151.01, 277.99, 236.99]  167944
#
# [167944 rows x 9 columns]

# %%
new_cropped_names_list = []
for index, row in df_complete.iterrows():
    bbox_used = row["bbox"]
    file_name_used = row["file_name"]
    index_used = row["index"]
    print(row["bbox"])
    #crop_image(file_name_used, bbox_used, index_used)
    new_cropped_names_list.append(crop_image(file_name_used, bbox_used, index_used))
# Out:
# [439.01, 187.01, 56.98000000000002, 53.98000000000002]
# [142.01, 185.01, 51.98000000000002, 54.98000000000002]
# [302.01, 97.01, 38.98000000000002, 161.98000000000002]
# [477.01, 113.01, 110.98000000000002, 91.98]
# [506.01, 99.01, 97.98000000000002, 239.98000000000002]
# [56.01, 118.01, 44.98, 67.98]
# [97.01, 244.01, 129.98000000000002, 129.98000000000002]
# [237.01, 96.01, 34.98000000000002, 90.98]
# [484.01, 14.01, 112.98000000000002, 376.98]
# [436.01, 144.01, 96.98000000000002, 62.98000000000002]
# [0, 246.01, 146.98000000000002, 71.98000000000002]
# [0, 48.01, 107.97999999999999, 299.98]
# [408.01, 161.01, 87.98000000000002, 111.98000000000002]
# [324.01, 122.01, 59.98000000000002, 70.98]
# [74.01, 176.01, 75.98, 98.98000000000002]
# [440.01, 163.01, 87.98000000000002, 63.98000000000002]
# [323.01, 180.01, 61.98000000000002, 50.98000000000002]
# [251.01, 202.01, 68.98000000000002, 69.98000000000002]
# [300.01, 160.01, 32.98000000000002, 80.98000000000002]
# [460.01, 169.01, 99.98000000000002, 45.98000000000002]
# [338.01, 79.01, 65.98000000000002, 175.98000000000002]
# [102.01, 109.01, 58.980000000000004, 220.98000000000002]
# /var/folders/zd/7pg6b__d3n57x_0cfph3xpzw0000gn/T/ipykernel_92910/4108140675.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# [152.01, 158.01, 76.98000000000002, 58.98000000000002]
# [251.01, 35.01, 26.980000000000018, 121.98000000000002]
# [431.01, 245.01, 202.98000000000002, 234.98000000000002]
# [127.00999999999999, 254.01, 166.98000000000002, 137.98000000000002]
# [332.01, 86.01, 69.98000000000002, 139.98000000000002]
# [480.01, 175.01, 32.98000000000002, 53.98000000000002]
# [77.01, 141.01, 103.98, 105.98000000000002]
# [239.01, 182.01, 85.98000000000002, 72.98000000000002]
# [346.01, 199.01, 120.98000000000002, 51.98000000000002]
# [164.01, 186.01, 129.98000000000002, 57.98000000000002]
# [288.01, 66.01, 65.98000000000002, 180.98000000000002]
# [213.01, 98.01, 202.98000000000002, 233.98000000000002]
# [326.01, 223.01, 281.98, 219.98000000000002]
# [194.01, 86.01, 80.98000000000002, 94.98]
# [355.01, 50.01, 29.980000000000018, 102.98000000000002]
# [151.01, 42.01, 87.98000000000002, 210.98000000000002]
# [326.01, 147.01, 87.98000000000002, 166.98000000000002]
# [535.01, 72.01, 46.98000000000002, 125.98]
# [136.01, 319.01, 344.98, 160.98000000000002]
# [248.01, 141.01, 51.98000000000002, 48.98000000000002]
# [168.01, 170.01, 87.98000000000002, 89.98000000000002]
# [57.01, 72.01, 91.98000000000002, 256.98]
# [268.01, 38.01, 104.98000000000002, 226.98000000000002]
# [168.01, 120.01, 112.98000000000002, 89.98]
# [331.01, 78.01, 72.98000000000002, 76.98]
# [58.01, 61.01, 148.98000000000002, 418.98]
# [427.01, 235.01, 212.98000000000002, 163.98000000000002]
# [387.01, 152.01, 84.98000000000002, 51.98000000000002]
# [332.01, 225.01, 102.98000000000002, 232.98000000000002]
# [147.01, 109.01, 62.98000000000002, 79.98]
# [278.01, 160.01, 105.98000000000002, 123.98000000000002]
# [392.01, 31.009999999999998, 55.98000000000002, 175.98000000000002]
# [131.01, 110.01, 120.98000000000002, 43.980000000000004]
# [149.01, 381.01, 178.98000000000002, 98.98000000000002]
# [472.01, 225.01, 145.98000000000002, 129.98000000000002]
# [55.01, 161.01, 84.98000000000002, 57.98000000000002]
# [310.01, 70.01, 44.98000000000002, 168.98000000000002]
# [454.01, 103.01, 35.98000000000002, 125.98]
# [334.01, 198.01, 159.98000000000002, 138.98000000000002]
# [233.01, 188.01, 149.98000000000002, 62.98000000000002]
# [298.01, 108.01, 44.98000000000002, 132.98000000000002]
# [241.01, 161.01, 50.98000000000002, 63.98000000000002]
# [38.01, 179.01, 93.98000000000002, 37.98000000000002]
# [485.01, 100.01, 37.98000000000002, 117.98]
# [573.01, 236.01, 66.98000000000002, 204.98000000000002]
# [300.01, 156.01, 42.98000000000002, 84.98000000000002]
# [250.01, 76.01, 95.98000000000002, 178.98000000000002]
# [63.010000000000005, 172.01, 81.98, 71.98000000000002]
# [464.01, 115.01, 31.980000000000018, 113.98]
# [261.01, 119.01, 70.98000000000002, 95.98]
# [391.01, 261.01, 117.98000000000002, 95.98000000000002]
# [289.01, 0, 64.98000000000002, 261.98]
# [238.01, 129.01, 122.98000000000002, 118.98000000000002]
# [249.01, 0, 138.98000000000002, 241.98000000000002]
# [266.01, 169.01, 97.98000000000002, 69.98000000000002]
# [76.01, 163.01, 74.98, 96.98000000000002]
# [257.01, 175.01, 91.98000000000002, 82.98000000000002]
# [323.01, 165.01, 47.98000000000002, 44.98000000000002]
# [469.01, 233.01, 132.98000000000002, 57.98000000000002]
# [183.01, 139.01, 67.98000000000002, 89.98000000000002]
# [431.01, 90.01, 50.98000000000002, 173.98000000000002]
# [267.01, 167.01, 102.98000000000002, 90.98000000000002]
# [0, 398.01, 24.979999999999997, 52.98000000000002]
# [359.01, 125.01, 63.98000000000002, 46.980000000000004]
# [369.01, 208.01, 106.98000000000002, 58.98000000000002]
# [266.01, 114.01, 51.98000000000002, 188.98000000000002]
# [311.01, 155.01, 49.98000000000002, 61.98000000000002]
# [140.01, 201.01, 73.98000000000002, 32.98000000000002]
# [143.01, 100.01, 129.98000000000002, 166.98000000000002]
# [511.01, 188.01, 62.98000000000002, 53.98000000000002]
# [237.01, 115.01, 102.98000000000002, 190.98000000000002]
# [438.01, 64.01, 52.98000000000002, 156.98000000000002]
# [109.01, 155.01, 104.98, 92.98000000000002]
# [488.01, 163.01, 62.98000000000002, 66.98000000000002]
# [498.01, 171.01, 141.98000000000002, 122.98000000000002]
# [102.01, 84.01, 39.980000000000004, 105.98]
# [0, 116.01, 77.97999999999999, 335.98]
# [294.01, 208.01, 54.98000000000002, 37.98000000000002]
# [398.01, 55.01, 75.98000000000002, 162.98000000000002]
# [125.01, 113.01, 116.98, 166.98000000000002]
# [464.01, 183.01, 88.98000000000002, 59.98000000000002]
# [105.01, 167.01, 61.980000000000004, 62.98000000000002]
# [317.01, 186.01, 87.98000000000002, 66.98000000000002]
# [390.01, 84.01, 84.98000000000002, 269.98]
# [225.01, 162.01, 86.98000000000002, 37.98000000000002]
# [205.01, 290.01, 163.98000000000002, 130.98000000000002]
# [257.01, 74.01, 96.98000000000002, 103.98]
# [297.01, 100.01, 138.98000000000002, 156.98000000000002]
# [0, 388.01, 168.98000000000002, 91.98000000000002]
# [400.01, 184.01, 85.98000000000002, 146.98000000000002]
# [362.01, 142.01, 86.98000000000002, 39.98000000000002]
# [215.01, 39.01, 48.98000000000002, 153.98000000000002]
# [405.01, 156.01, 45.98000000000002, 81.98000000000002]
# [127.00999999999999, 107.01, 86.98000000000002, 168.98000000000002]
# [60.01, 180.01, 111.98000000000002, 50.98000000000002]
# [259.01, 0, 165.98000000000002, 391.98]
# [288.01, 84.01, 29.980000000000018, 56.980000000000004]
# [512.01, 84.01, 118.98000000000002, 262.98]
# [328.01, 78.01, 33.98000000000002, 105.98]
# [0, 265.01, 193.98000000000002, 177.98000000000002]
# [85.01, 43.01, 106.98, 244.98000000000002]
# [470.01, 92.01, 66.98000000000002, 127.98]
# [279.01, 33.01, 26.980000000000018, 152.98000000000002]
# [294.01, 187.01, 112.98000000000002, 189.98000000000002]
# [142.01, 126.01, 142.98000000000002, 121.98]
# [239.01, 162.01, 49.98000000000002, 194.98000000000002]
# [399.01, 122.01, 71.98000000000002, 79.98]
# [9.01, 152.01, 176.98000000000002, 136.98000000000002]
# [447.01, 132.01, 99.98000000000002, 55.98000000000002]
# [165.01, 45.01, 63.98000000000002, 151.98000000000002]
# [467.01, 323.01, 138.98000000000002, 115.98000000000002]
# [0, 131.01, 137.98000000000002, 261.98]
# [358.01, 128.01, 156.98000000000002, 61.98000000000002]
# [243.01, 213.01, 190.98000000000002, 130.98000000000002]
# [455.01, 143.01, 89.98000000000002, 68.98000000000002]
# [79.01, 68.01, 63.980000000000004, 163.98000000000002]
# [0, 36.01, 87.97999999999999, 217.98000000000002]
# [394.01, 197.01, 112.98000000000002, 124.98000000000002]
# [378.01, 137.01, 81.98000000000002, 68.98000000000002]
# [225.01, 48.01, 127.98000000000002, 136.98000000000002]
# [301.01, 78.01, 277.98, 332.98]
# [467.01, 113.01, 51.98000000000002, 47.980000000000004]
# [184.01, 362.01, 228.98000000000002, 117.98000000000002]
# [333.01, 201.01, 136.98000000000002, 64.98000000000002]
# [0, 200.01, 64.97999999999999, 56.98000000000002]
# [56.01, 127.00999999999999, 138.98000000000002, 165.98000000000002]
# [296.01, 162.01, 40.98000000000002, 58.98000000000002]
# [445.01, 186.01, 40.98000000000002, 64.98000000000002]
# [342.01, 108.01, 50.98000000000002, 91.98]
# [0, 396.01, 125.97999999999999, 83.98000000000002]
# [499.01, 150.01, 60.98000000000002, 60.98000000000002]
# [98.01, 183.01, 116.98, 50.98000000000002]
# [423.01, 187.01, 76.98000000000002, 49.98000000000002]
# [83.01, 192.01, 99.98, 66.98000000000002]
# [399.01, 136.01, 47.98000000000002, 80.98000000000002]
# [72.01, 212.01, 189.98000000000002, 90.98000000000002]
# [382.01, 33.01, 26.980000000000018, 137.98000000000002]
# [228.01, 152.01, 87.98000000000002, 51.98000000000002]
# [423.01, 379.01, 106.98000000000002, 100.98000000000002]
# [92.01, 178.01, 154.98000000000002, 112.98000000000002]
# [334.01, 68.01, 51.98000000000002, 192.98000000000002]
# [432.01, 161.01, 40.98000000000002, 20.980000000000018]
# [362.01, 0, 76.98000000000002, 376.98]
# [87.01, 164.01, 85.98, 72.98000000000002]
# [76.01, 147.01, 147.98000000000002, 176.98000000000002]
# [228.01, 152.01, 86.98000000000002, 76.98000000000002]
# [424.01, 160.01, 130.98000000000002, 73.98000000000002]
# [190.01, 148.01, 56.98000000000002, 36.98000000000002]
# [323.01, 160.01, 95.98000000000002, 219.98000000000002]
# [65.01, 367.01, 161.98000000000002, 112.98000000000002]
# [437.01, 111.01, 66.98000000000002, 55.980000000000004]
# [207.01, 172.01, 102.98000000000002, 82.98000000000002]
# [0, 453.01, 98.97999999999999, 26.980000000000018]
# [159.01, 132.01, 69.98000000000002, 67.98000000000002]
# [490.01, 57.01, 53.98000000000002, 171.98000000000002]
# [293.01, 103.01, 56.98000000000002, 87.98]
# [207.01, 82.01, 235.98000000000002, 167.98000000000002]
# [436.01, 146.01, 77.98000000000002, 135.98000000000002]
# [123.01, 183.01, 68.98, 69.98000000000002]
# [304.01, 125.01, 50.98000000000002, 95.98]
# [401.01, 191.01, 100.98000000000002, 68.98000000000002]
# [172.01, 176.01, 92.98000000000002, 72.98000000000002]
# [67.01, 216.01, 166.98000000000002, 124.98000000000002]
# [393.01, 156.01, 48.98000000000002, 39.98000000000002]
# [384.01, 144.01, 79.98000000000002, 183.98000000000002]
# [204.01, 76.01, 87.98000000000002, 101.98]
# [104.01, 163.01, 74.98, 98.98000000000002]
# [445.01, 116.01, 106.98000000000002, 57.980000000000004]
# [151.01, 275.01, 67.98000000000002, 204.98000000000002]
# [271.01, 214.01, 79.98000000000002, 114.98000000000002]
# [490.01, 169.01, 45.98000000000002, 49.98000000000002]
# [180.01, 134.01, 97.98000000000002, 87.98000000000002]
# [118.01, 195.01, 149.98000000000002, 64.98000000000002]
# [151.01, 154.01, 67.98000000000002, 107.98000000000002]
# [226.01, 186.01, 63.98000000000002, 48.98000000000002]
# [436.01, 177.01, 74.98000000000002, 59.98000000000002]
# [260.01, 169.01, 131.98000000000002, 73.98000000000002]
# [171.01, 205.01, 114.98000000000002, 77.98000000000002]
# [337.01, 173.01, 104.98000000000002, 54.98000000000002]
# [67.01, 173.01, 136.98000000000002, 96.98000000000002]
# [306.01, 89.01, 150.98000000000002, 211.98000000000002]
# [155.01, 144.01, 92.98000000000002, 70.98000000000002]
# [515.01, 89.01, 79.98000000000002, 139.98000000000002]
# [285.01, 160.01, 46.98000000000002, 48.98000000000002]
# [306.01, 201.01, 161.98000000000002, 109.98000000000002]
# [166.01, 45.01, 138.98000000000002, 137.98000000000002]
# [67.01, 119.01, 122.98, 236.98000000000002]
# [493.01, 167.01, 121.98000000000002, 107.98000000000002]
# [233.01, 151.01, 163.98000000000002, 93.98000000000002]
# [249.01, 406.01, 212.98000000000002, 73.98000000000002]
# [201.01, 116.01, 89.98000000000002, 58.980000000000004]
# [443.01, 105.01, 52.98000000000002, 66.98]
# [100.01, 167.01, 89.98, 235.98000000000002]
# [401.01, 169.01, 67.98000000000002, 50.98000000000002]
# [403.01, 196.01, 165.98000000000002, 157.98000000000002]
# [57.01, 172.01, 121.98000000000002, 59.98000000000002]
# [382.01, 182.01, 98.98000000000002, 255.98000000000002]
# [594.01, 139.01, 45.98000000000002, 84.98000000000002]
# [42.01, 65.01, 76.97999999999999, 271.98]
# [124.01, 96.01, 69.98, 72.98]
# [186.01, 86.01, 86.98000000000002, 91.98]
# [585.01, 186.01, 54.98000000000002, 101.98000000000002]
# [111.01, 161.01, 136.98000000000002, 144.98000000000002]
# [0, 344.01, 280.98, 135.98000000000002]
# [374.01, 189.01, 58.98000000000002, 81.98000000000002]
# [465.01, 93.01, 35.98000000000002, 109.98]
# [128.01, 111.01, 55.98000000000002, 95.98]
# [322.01, 204.01, 108.98000000000002, 64.98000000000002]
# [122.01, 180.01, 87.98, 60.98000000000002]
# [369.01, 176.01, 105.98000000000002, 50.98000000000002]
# [525.01, 13.01, 114.98000000000002, 246.98000000000002]
# [238.01, 71.01, 97.98000000000002, 56.980000000000004]
# [105.01, 242.01, 212.98000000000002, 78.98000000000002]
# [0, 296.01, 257.98, 183.98000000000002]
# [323.01, 56.01, 55.98000000000002, 132.98000000000002]
# [183.01, 258.01, 150.98000000000002, 134.98000000000002]
# [305.01, 118.01, 32.98000000000002, 124.98]
# [165.01, 271.01, 181.98000000000002, 156.98000000000002]
# [104.01, 95.01, 71.98, 143.98000000000002]
# [451.01, 180.01, 168.98000000000002, 105.98000000000002]
# [317.01, 98.01, 65.98000000000002, 76.98]
# [346.01, 65.01, 34.98000000000002, 167.98000000000002]
# [210.01, 147.01, 79.98000000000002, 36.98000000000002]
# [354.01, 301.01, 131.98000000000002, 177.98000000000002]
# [356.01, 120.01, 80.98000000000002, 112.98]
# [199.01, 95.01, 52.98000000000002, 158.98000000000002]
# [405.01, 160.01, 59.98000000000002, 34.98000000000002]
# [335.01, 349.01, 304.98, 130.98000000000002]
# [70.01, 160.01, 104.98, 60.98000000000002]
# [366.01, 207.01, 39.98000000000002, 79.98000000000002]
# [431.01, 187.01, 96.98000000000002, 43.98000000000002]
# [38.01, 190.01, 139.98000000000002, 48.98000000000002]
# [0, 283.01, 93.97999999999999, 41.98000000000002]
# [502.01, 147.01, 88.98000000000002, 67.98000000000002]
# [349.01, 129.01, 125.98000000000002, 131.98000000000002]
# [207.01, 143.01, 72.98000000000002, 61.98000000000002]
# [136.01, 150.01, 144.98000000000002, 111.98000000000002]
# [127.00999999999999, 199.01, 113.98000000000002, 45.98000000000002]
# [396.01, 174.01, 85.98000000000002, 74.98000000000002]
# [32.01, 198.01, 192.98000000000002, 127.98000000000002]
# [433.01, 140.01, 48.98000000000002, 60.98000000000002]
# [399.01, 36.01, 44.98000000000002, 200.98000000000002]
# [563.01, 100.01, 76.98000000000002, 236.98000000000002]
# [172.01, 204.01, 93.98000000000002, 97.98000000000002]
# [111.01, 145.01, 75.98, 45.98000000000002]
# [420.01, 67.01, 59.98000000000002, 136.98000000000002]
# [130.01, 65.01, 35.98000000000002, 116.98]
# [83.01, 310.01, 253.98000000000002, 161.98000000000002]
# [447.01, 196.01, 77.98000000000002, 142.98000000000002]
# [237.01, 153.01, 114.98000000000002, 29.980000000000018]
# [40.01, 305.01, 217.98000000000002, 86.98000000000002]
# [422.01, 132.01, 76.98000000000002, 126.98000000000002]
# [281.01, 201.01, 81.98000000000002, 48.98000000000002]
# [349.01, 81.01, 25.980000000000018, 106.98]
# [264.01, 82.01, 109.98000000000002, 329.98]
# [176.01, 195.01, 118.98000000000002, 62.98000000000002]
# [291.01, 183.01, 62.98000000000002, 67.98000000000002]
# [328.01, 118.01, 70.98000000000002, 86.98]
# [267.01, 35.01, 108.98000000000002, 299.98]
# [253.01, 146.01, 127.98000000000002, 45.98000000000002]
# [127.00999999999999, 143.01, 99.98000000000002, 73.98000000000002]
# [442.01, 184.01, 120.98000000000002, 129.98000000000002]
# [219.01, 199.01, 151.98000000000002, 176.98000000000002]
# [145.01, 150.01, 119.98000000000002, 286.98]
# [342.01, 59.01, 85.98000000000002, 123.98000000000002]
# [269.01, 51.01, 111.98000000000002, 245.98000000000002]
# [501.01, 165.01, 138.98000000000002, 298.98]
# [93.01, 157.01, 96.98, 66.98000000000002]
# [356.01, 99.01, 40.98000000000002, 104.98]
# [251.01, 57.01, 38.98000000000002, 146.98000000000002]
# [360.01, 235.01, 93.98000000000002, 78.98000000000002]
# [333.01, 107.01, 94.98000000000002, 96.98]
# [128.01, 167.01, 119.98000000000002, 50.98000000000002]
# [261.01, 215.01, 96.98000000000002, 128.98000000000002]
# [408.01, 185.01, 80.98000000000002, 106.98000000000002]
# [213.01, 142.01, 32.98000000000002, 67.98000000000002]
# [217.01, 127.00999999999999, 62.98000000000002, 138.98000000000002]
# [481.01, 221.01, 103.98000000000002, 91.98000000000002]
# [319.01, 163.01, 77.98000000000002, 60.98000000000002]
# [215.01, 105.01, 36.98000000000002, 95.98]
# [310.01, 120.01, 51.98000000000002, 163.98000000000002]
# [281.01, 129.01, 218.98000000000002, 282.98]
# [213.01, 97.01, 34.98000000000002, 128.98000000000002]
# [230.01, 333.01, 152.98000000000002, 94.98000000000002]
# [344.01, 125.01, 108.98000000000002, 64.98]
# [388.01, 190.01, 32.98000000000002, 37.98000000000002]
# [489.01, 98.01, 85.98000000000002, 242.98000000000002]
# [183.01, 186.01, 62.98000000000002, 69.98000000000002]
# [180.01, 155.01, 75.98000000000002, 53.98000000000002]
# [412.01, 40.01, 73.98000000000002, 112.98000000000002]
# [419.01, 59.01, 55.98000000000002, 182.98000000000002]
# [116.01, 128.01, 85.98, 57.98000000000002]
# [0, 291.01, 173.98000000000002, 95.98000000000002]
# [459.01, 240.01, 130.98000000000002, 111.98000000000002]
# [95.01, 52.01, 43.980000000000004, 149.98000000000002]
# [212.01, 252.01, 193.98000000000002, 140.98000000000002]
# [462.01, 177.01, 137.98000000000002, 50.98000000000002]
# [201.01, 128.01, 112.98000000000002, 88.98000000000002]
# [239.01, 278.01, 181.98000000000002, 102.98000000000002]
# [325.01, 121.01, 71.98000000000002, 86.98]
# [177.01, 76.01, 70.98000000000002, 262.98]
# [340.01, 138.01, 59.98000000000002, 58.98000000000002]
# [379.01, 126.01, 99.98000000000002, 46.980000000000004]
# [93.01, 315.01, 256.98, 164.98000000000002]
# [147.01, 147.01, 90.98000000000002, 83.98000000000002]
# [325.01, 110.01, 53.98000000000002, 91.98]
# [198.01, 250.01, 120.98000000000002, 94.98000000000002]
# [171.01, 147.01, 109.98000000000002, 78.98000000000002]
# [201.01, 152.01, 67.98000000000002, 39.98000000000002]
# [353.01, 192.01, 156.98000000000002, 108.98000000000002]
# [534.01, 150.01, 37.98000000000002, 63.98000000000002]
# [0, 300.01, 171.98000000000002, 179.98000000000002]
# [378.01, 131.01, 46.98000000000002, 92.98000000000002]
# [177.01, 182.01, 89.98000000000002, 40.98000000000002]
# [263.01, 157.01, 93.98000000000002, 164.98000000000002]
# [395.01, 176.01, 78.98000000000002, 50.98000000000002]
# [113.01, 180.01, 51.980000000000004, 77.98000000000002]
# [316.01, 199.01, 126.98000000000002, 64.98000000000002]
# [0, 208.01, 129.98000000000002, 86.98000000000002]
# [209.01, 109.01, 59.98000000000002, 55.980000000000004]
# [510.01, 124.01, 49.98000000000002, 64.98]
# [211.01, 207.01, 79.98000000000002, 99.98000000000002]
# [510.01, 331.01, 129.98000000000002, 148.98000000000002]
# [240.01, 64.01, 82.98000000000002, 183.98000000000002]
# [363.01, 327.01, 276.98, 137.98000000000002]
# [244.01, 28.01, 59.98000000000002, 109.98]
# [277.01, 138.01, 92.98000000000002, 129.98000000000002]
# [413.01, 148.01, 63.98000000000002, 77.98000000000002]
# [173.01, 149.01, 67.98000000000002, 58.98000000000002]
# [248.01, 164.01, 183.98000000000002, 204.98000000000002]
# [277.01, 104.01, 115.98000000000002, 79.98]
# [101.01, 180.01, 137.98000000000002, 129.98000000000002]
# [396.01, 167.01, 78.98000000000002, 133.98000000000002]
# [419.01, 131.01, 50.98000000000002, 88.98000000000002]
# [184.01, 180.01, 57.98000000000002, 50.98000000000002]
# [84.01, 162.01, 303.98, 317.98]
# [272.01, 185.01, 73.98000000000002, 23.980000000000018]
# [396.01, 124.01, 78.98000000000002, 103.98]
# [192.01, 210.01, 89.98000000000002, 139.98000000000002]
# [231.01, 75.01, 58.98000000000002, 139.98000000000002]
# [206.01, 215.01, 175.98000000000002, 145.98000000000002]
# [340.01, 150.01, 49.98000000000002, 51.98000000000002]
# [346.01, 137.01, 134.98000000000002, 125.98000000000002]
# [187.01, 127.00999999999999, 83.98000000000002, 97.98000000000002]
# [381.01, 144.01, 91.98000000000002, 62.98000000000002]
# [46.01, 132.01, 82.98000000000002, 195.98000000000002]
# [284.01, 150.01, 89.98000000000002, 96.98000000000002]
# [441.01, 163.01, 92.98000000000002, 64.98000000000002]
# [237.01, 221.01, 161.98000000000002, 109.98000000000002]
# [54.01, 84.01, 53.98, 124.98]
# [469.01, 160.01, 134.98000000000002, 137.98000000000002]
# [217.01, 190.01, 57.98000000000002, 36.98000000000002]
# [130.01, 170.01, 197.98000000000002, 183.98000000000002]
# [323.01, 163.01, 156.98000000000002, 50.98000000000002]
# [276.01, 153.01, 76.98000000000002, 46.98000000000002]
# [41.01, 57.01, 110.98000000000002, 269.98]
# [452.01, 205.01, 60.98000000000002, 65.98000000000002]
# [230.01, 151.01, 88.98000000000002, 45.98000000000002]
# [160.01, 219.01, 220.98000000000002, 113.98000000000002]
# [394.01, 155.01, 94.98000000000002, 118.98000000000002]
# [259.01, 209.01, 106.98000000000002, 38.98000000000002]
# [285.01, 136.01, 64.98000000000002, 116.98000000000002]
# [103.01, 193.01, 42.980000000000004, 46.98000000000002]
# [517.01, 189.01, 48.98000000000002, 55.98000000000002]
# [342.01, 320.01, 151.98000000000002, 77.98000000000002]
# [465.01, 158.01, 42.98000000000002, 64.98000000000002]
# [33.01, 117.01, 56.98, 96.98]
# [339.01, 152.01, 36.98000000000002, 85.98000000000002]
# [95.01, 276.01, 136.98000000000002, 111.98000000000002]
# [343.01, 77.01, 98.98000000000002, 109.98]
# [399.01, 189.01, 86.98000000000002, 33.98000000000002]
# [438.01, 28.01, 77.98000000000002, 243.98000000000002]
# [161.01, 168.01, 83.98000000000002, 64.98000000000002]
# [18.01, 242.01, 221.98000000000002, 174.98000000000002]
# [277.01, 88.01, 25.980000000000018, 107.98]
# [249.01, 85.01, 42.98000000000002, 104.98]
# [194.01, 177.01, 57.98000000000002, 61.98000000000002]
# [385.01, 159.01, 117.98000000000002, 56.98000000000002]
# [123.01, 127.00999999999999, 62.980000000000004, 207.98000000000002]
# [470.01, 233.01, 133.98000000000002, 157.98000000000002]
# [381.01, 43.01, 195.98000000000002, 381.98]
# [489.01, 62.01, 38.98000000000002, 158.98000000000002]
# [100.01, 76.01, 28.980000000000004, 115.98]
# [230.01, 135.01, 111.98000000000002, 80.98000000000002]
# [569.01, 183.01, 70.98000000000002, 162.98000000000002]
# [80.01, 72.01, 52.980000000000004, 159.98000000000002]
# [293.01, 210.01, 56.98000000000002, 37.98000000000002]
# [257.01, 134.01, 87.98000000000002, 270.98]
# [281.01, 136.01, 62.98000000000002, 57.98000000000002]
# [349.01, 249.01, 215.98000000000002, 143.98000000000002]
# [117.01, 169.01, 43.980000000000004, 83.98000000000002]
# [193.01, 56.01, 74.98000000000002, 147.98000000000002]
# [449.01, 168.01, 109.98000000000002, 56.98000000000002]
# [240.01, 31.009999999999998, 66.98000000000002, 171.98000000000002]
# [312.01, 180.01, 184.98000000000002, 148.98000000000002]
# [65.01, 129.01, 145.98000000000002, 105.98000000000002]
# [504.01, 93.01, 67.98000000000002, 160.98000000000002]
# [230.01, 136.01, 98.98000000000002, 58.98000000000002]
# [353.01, 173.01, 81.98000000000002, 205.98000000000002]
# [274.01, 141.01, 92.98000000000002, 113.98000000000002]
# [138.01, 208.01, 167.98000000000002, 135.98000000000002]
# [346.01, 111.01, 44.98000000000002, 92.98]
# [402.01, 51.01, 51.98000000000002, 83.98000000000002]
# [267.01, 110.01, 160.98000000000002, 161.98000000000002]
# [0, 363.01, 151.98000000000002, 116.98000000000002]
# [348.01, 62.01, 195.98000000000002, 373.98]
# [380.01, 14.01, 58.98000000000002, 164.98000000000002]
# [0, 302.01, 145.98000000000002, 177.98000000000002]
# [43.01, 35.01, 79.97999999999999, 218.98000000000002]
# [432.01, 60.01, 88.98000000000002, 71.98000000000002]
# [469.01, 138.01, 121.98000000000002, 81.98000000000002]
# [49.01, 205.01, 101.98000000000002, 166.98000000000002]
# [95.01, 160.01, 62.980000000000004, 43.98000000000002]
# [425.01, 135.01, 100.98000000000002, 145.98000000000002]
# [483.01, 156.01, 55.98000000000002, 60.98000000000002]
# [137.01, 147.01, 107.98000000000002, 72.98000000000002]
# [119.01, 282.01, 220.98000000000002, 127.98000000000002]
# [376.01, 144.01, 263.98, 335.98]
# [43.01, 192.01, 132.98000000000002, 152.98000000000002]
# [335.01, 36.01, 62.98000000000002, 107.98000000000002]
# [234.01, 90.01, 47.98000000000002, 108.98]
# [456.01, 60.01, 69.98000000000002, 186.98000000000002]
# [248.01, 131.01, 63.98000000000002, 113.98000000000002]
# [192.01, 205.01, 139.98000000000002, 109.98000000000002]
# [435.01, 190.01, 39.98000000000002, 67.98000000000002]
# [284.01, 184.01, 79.98000000000002, 53.98000000000002]
# [178.01, 182.01, 40.98000000000002, 54.98000000000002]
# [300.01, 198.01, 38.98000000000002, 48.98000000000002]
# [349.01, 140.01, 290.98, 256.98]
# [25.01, 166.01, 214.98000000000002, 114.98000000000002]
# [328.01, 136.01, 78.98000000000002, 45.98000000000002]
# [14.01, 168.01, 61.98, 73.98000000000002]
# [185.01, 321.01, 273.98, 158.98000000000002]
# [310.01, 130.01, 71.98000000000002, 41.98000000000002]
# [502.01, 44.01, 99.98000000000002, 211.98000000000002]
# [331.01, 104.01, 56.98000000000002, 52.980000000000004]
# [0, 341.01, 90.97999999999999, 138.98000000000002]
# [362.01, 152.01, 109.98000000000002, 101.98000000000002]
# [290.01, 160.01, 68.98000000000002, 76.98000000000002]
# [47.01, 133.01, 135.98000000000002, 146.98000000000002]
# [469.01, 88.01, 38.98000000000002, 113.98]
# [241.01, 306.01, 393.98, 173.98000000000002]
# [204.01, 132.01, 70.98000000000002, 69.98000000000002]
# [83.01, 232.01, 108.98, 64.98000000000002]
# [221.01, 127.00999999999999, 46.98000000000002, 89.98000000000002]
# [429.01, 114.01, 32.98000000000002, 97.98]
# [369.01, 83.01, 81.98000000000002, 205.98000000000002]
# [152.01, 190.01, 102.98000000000002, 114.98000000000002]
# [359.01, 158.01, 99.98000000000002, 75.98000000000002]
# [462.01, 226.01, 107.98000000000002, 125.98000000000002]
# [415.01, 139.01, 64.98000000000002, 57.98000000000002]
# [210.01, 89.01, 49.98000000000002, 164.98000000000002]
# [239.01, 88.01, 44.98000000000002, 107.98]
# [53.01, 158.01, 116.98000000000002, 207.98000000000002]
# [336.01, 99.01, 60.98000000000002, 189.98000000000002]
# [437.01, 154.01, 29.980000000000018, 58.98000000000002]
# [55.01, 208.01, 98.98000000000002, 43.98000000000002]
# [341.01, 137.01, 103.98000000000002, 76.98000000000002]
# [171.01, 134.01, 178.98000000000002, 153.98000000000002]
# [320.01, 229.01, 159.98000000000002, 165.98000000000002]
# [217.01, 135.01, 102.98000000000002, 52.98000000000002]
# [302.01, 123.01, 85.98000000000002, 59.980000000000004]
# [140.01, 8.01, 128.98000000000002, 389.98]
# [390.01, 177.01, 89.98000000000002, 154.98000000000002]
# [70.01, 88.01, 74.98, 130.98000000000002]
# [288.01, 312.01, 258.98, 167.98000000000002]
# [365.01, 104.01, 27.980000000000018, 60.980000000000004]
# [103.01, 189.01, 167.98000000000002, 85.98000000000002]
# [440.01, 181.01, 32.98000000000002, 64.98000000000002]
# [253.01, 156.01, 90.98000000000002, 64.98000000000002]
# [393.01, 171.01, 52.98000000000002, 79.98000000000002]
# [69.01, 125.01, 70.98, 152.98000000000002]
# [366.01, 179.01, 84.98000000000002, 21.980000000000018]
# [272.01, 290.01, 289.98, 188.98000000000002]
# [226.01, 126.01, 35.98000000000002, 84.98]
# [435.01, 114.01, 58.98000000000002, 56.980000000000004]
# [328.01, 70.01, 86.98000000000002, 196.98000000000002]
# [181.01, 121.01, 90.98000000000002, 48.980000000000004]
# [81.01, 139.01, 122.98, 198.98000000000002]
# [104.01, 439.01, 122.98, 40.98000000000002]
# [210.01, 158.01, 63.98000000000002, 85.98000000000002]
# [380.01, 191.01, 30.980000000000018, 58.98000000000002]
# [154.01, 216.01, 166.98000000000002, 165.98000000000002]
# [294.01, 69.01, 42.98000000000002, 114.98]
# [333.01, 59.01, 78.98000000000002, 189.98000000000002]
# [477.01, 307.01, 162.98000000000002, 115.98000000000002]
# [121.01, 144.01, 48.980000000000004, 66.98000000000002]
# [265.01, 132.01, 100.98000000000002, 67.98000000000002]
# [0, 0, 152.98000000000002, 408.98]
# [422.01, 169.01, 106.98000000000002, 31.980000000000018]
# [134.01, 143.01, 74.98000000000002, 56.98000000000002]
# [300.01, 164.01, 86.98000000000002, 32.98000000000002]
# [323.01, 95.01, 58.98000000000002, 184.98000000000002]
# [454.01, 275.01, 185.98000000000002, 195.98000000000002]
# [80.01, 141.01, 62.980000000000004, 62.98000000000002]
# [391.01, 231.01, 144.98000000000002, 98.98000000000002]
# [403.01, 162.01, 101.98000000000002, 73.98000000000002]
# [480.01, 163.01, 86.98000000000002, 236.98000000000002]
# [216.01, 111.01, 28.980000000000018, 59.980000000000004]
# [270.01, 109.01, 90.98000000000002, 178.98000000000002]
# [174.01, 53.01, 56.98000000000002, 130.98000000000002]
# [133.01, 85.01, 295.98, 271.98]
# [433.01, 195.01, 132.98000000000002, 58.98000000000002]
# [371.01, 189.01, 169.98000000000002, 131.98000000000002]
# [353.01, 40.01, 43.98000000000002, 124.98000000000002]
# [1.0099999999999998, 209.01, 201.98000000000002, 147.98000000000002]
# [427.01, 100.01, 60.98000000000002, 199.98000000000002]
# [104.01, 193.01, 65.98, 69.98000000000002]
# [213.01, 77.01, 142.98000000000002, 317.98]
# [481.01, 125.01, 87.98000000000002, 59.980000000000004]
# [152.01, 44.01, 53.98000000000002, 148.98000000000002]
# [343.01, 155.01, 74.98000000000002, 48.98000000000002]
# [163.01, 90.01, 84.98000000000002, 238.98000000000002]
# [398.01, 114.01, 53.98000000000002, 95.98]
# [352.01, 134.01, 88.98000000000002, 123.98000000000002]
# [73.01, 46.01, 80.98, 185.98000000000002]
# [219.01, 125.01, 217.98000000000002, 224.98000000000002]
# [420.01, 180.01, 107.98000000000002, 54.98000000000002]
# [122.01, 118.01, 52.980000000000004, 128.98000000000002]
# [247.01, 181.01, 112.98000000000002, 78.98000000000002]
# [452.01, 119.01, 111.98000000000002, 100.98]
# [239.01, 86.01, 24.980000000000018, 131.98000000000002]
# [479.01, 167.01, 160.98000000000002, 312.98]
# [306.01, 141.01, 101.98000000000002, 101.98000000000002]
# [78.01, 73.01, 59.980000000000004, 138.98000000000002]
# [355.01, 1.0099999999999998, 49.98000000000002, 149.98000000000002]
# [178.01, 300.01, 166.98000000000002, 139.98000000000002]
# [193.01, 188.01, 176.98000000000002, 90.98000000000002]
# [456.01, 182.01, 60.98000000000002, 76.98000000000002]
# [236.01, 162.01, 67.98000000000002, 40.98000000000002]
# [105.01, 215.01, 128.98000000000002, 95.98000000000002]
# [268.01, 134.01, 87.98000000000002, 116.98000000000002]
# [412.01, 260.01, 187.98000000000002, 219.98000000000002]
# [268.01, 159.01, 87.98000000000002, 62.98000000000002]
# [187.01, 148.01, 36.98000000000002, 55.98000000000002]
# [378.01, 174.01, 93.98000000000002, 83.98000000000002]
# [393.01, 84.01, 55.98000000000002, 177.98000000000002]
# [402.01, 139.01, 50.98000000000002, 58.98000000000002]
# [474.01, 199.01, 158.98000000000002, 161.98000000000002]
# [132.01, 155.01, 96.98000000000002, 68.98000000000002]
# [0, 134.01, 82.97999999999999, 141.98000000000002]
# [157.01, 138.01, 127.98000000000002, 199.98000000000002]
# [490.01, 212.01, 105.98000000000002, 101.98000000000002]
# [481.01, 152.01, 42.98000000000002, 56.98000000000002]
# [151.01, 161.01, 92.98000000000002, 43.98000000000002]
# [147.01, 94.01, 61.98000000000002, 154.98000000000002]
# [174.01, 99.01, 56.98000000000002, 235.98000000000002]
# [405.01, 172.01, 223.98000000000002, 186.98000000000002]
# [416.01, 148.01, 32.98000000000002, 57.98000000000002]
# [218.01, 160.01, 123.98000000000002, 85.98000000000002]
# [209.01, 152.01, 64.98000000000002, 39.98000000000002]
# [308.01, 116.01, 31.980000000000018, 125.98]
# [148.01, 147.01, 155.98000000000002, 121.98000000000002]
# [308.01, 153.01, 135.98000000000002, 72.98000000000002]
# [233.01, 79.01, 54.98000000000002, 91.98]
# [364.01, 41.01, 189.98000000000002, 341.98]
# [473.01, 162.01, 88.98000000000002, 95.98000000000002]
# [45.01, 22.01, 91.98000000000002, 251.98000000000002]
# [256.01, 111.01, 34.98000000000002, 110.98]
# [0, 245.01, 194.98000000000002, 162.98000000000002]
# [60.01, 161.01, 85.98000000000002, 64.98000000000002]
# [499.01, 133.01, 57.98000000000002, 88.98000000000002]
# [457.01, 175.01, 60.98000000000002, 73.98000000000002]
# [281.01, 218.01, 84.98000000000002, 29.980000000000018]
# [407.01, 179.01, 139.98000000000002, 80.98000000000002]
# [381.01, 82.01, 23.980000000000018, 126.98]
# [236.01, 178.01, 62.98000000000002, 61.98000000000002]
# [44.01, 201.01, 107.98000000000002, 95.98000000000002]
# [203.01, 173.01, 65.98000000000002, 68.98000000000002]
# [501.01, 150.01, 75.98000000000002, 66.98000000000002]
# [280.01, 202.01, 125.98000000000002, 172.98000000000002]
# [143.01, 119.01, 44.98000000000002, 94.98]
# [168.01, 152.01, 104.98000000000002, 73.98000000000002]
# [334.01, 139.01, 168.98000000000002, 149.98000000000002]
# [18.01, 230.01, 234.98000000000002, 108.98000000000002]
# [316.01, 141.01, 63.98000000000002, 62.98000000000002]
# [338.01, 197.01, 113.98000000000002, 54.98000000000002]
# [33.01, 217.01, 101.98000000000002, 219.98000000000002]
# [391.01, 113.01, 74.98000000000002, 65.98]
# [255.01, 48.01, 34.98000000000002, 134.98000000000002]
# [446.01, 64.01, 125.98000000000002, 229.98000000000002]
# [134.01, 47.01, 87.98000000000002, 280.98]
# [378.01, 146.01, 41.98000000000002, 78.98000000000002]
# [503.01, 43.01, 119.98000000000002, 315.98]
# [137.01, 190.01, 65.98000000000002, 107.98000000000002]
# [227.01, 97.01, 37.98000000000002, 90.98]
# [125.01, 188.01, 45.980000000000004, 63.98000000000002]
# [109.01, 288.01, 215.98000000000002, 134.98000000000002]
# [374.01, 206.01, 91.98000000000002, 66.98000000000002]
# [437.01, 161.01, 72.98000000000002, 49.98000000000002]
# [256.01, 122.01, 81.98000000000002, 88.98]
# [480.01, 103.01, 47.98000000000002, 180.98000000000002]
# [246.01, 182.01, 110.98000000000002, 70.98000000000002]
# [174.01, 153.01, 77.98000000000002, 52.98000000000002]
# [43.01, 211.01, 158.98000000000002, 99.98000000000002]
# [481.01, 45.01, 94.98000000000002, 308.98]
# [266.01, 85.01, 93.98000000000002, 78.98]
# [245.01, 134.01, 79.98000000000002, 50.98000000000002]
# [31.009999999999998, 271.01, 274.98, 113.98000000000002]
# [303.01, 156.01, 125.98000000000002, 81.98000000000002]
# [310.01, 185.01, 192.98000000000002, 105.98000000000002]
# [473.01, 36.01, 166.98000000000002, 206.98000000000002]
# [0, 316.01, 223.98000000000002, 163.98000000000002]
# [211.01, 112.01, 109.98000000000002, 55.980000000000004]
# [483.01, 41.01, 94.98000000000002, 191.98000000000002]
# [259.01, 181.01, 140.98000000000002, 65.98000000000002]
# [268.01, 272.01, 129.98000000000002, 207.98000000000002]
# [114.01, 122.01, 82.98, 67.98]
# [425.01, 305.01, 214.98000000000002, 108.98000000000002]
# [25.01, 180.01, 112.98, 77.98000000000002]
# [422.01, 159.01, 119.98000000000002, 57.98000000000002]
# [185.01, 139.01, 94.98000000000002, 70.98000000000002]
# [376.01, 36.01, 27.980000000000018, 110.98000000000002]
# [369.01, 137.01, 105.98000000000002, 84.98000000000002]
# [127.00999999999999, 58.01, 57.98000000000002, 226.98000000000002]
# [28.01, 388.01, 114.98, 91.98000000000002]
# [187.01, 65.01, 106.98000000000002, 111.98]
# [216.01, 69.01, 93.98000000000002, 217.98000000000002]
# [494.01, 22.01, 99.98000000000002, 306.98]
# [323.01, 240.01, 154.98000000000002, 122.98000000000002]
# [531.01, 190.01, 53.98000000000002, 86.98000000000002]
# [95.01, 113.01, 30.97999999999999, 110.98]
# [269.01, 61.01, 23.980000000000018, 126.98000000000002]
# [355.01, 172.01, 130.98000000000002, 92.98000000000002]
# [162.01, 142.01, 148.98000000000002, 296.98]
# [227.01, 68.01, 95.98000000000002, 99.98]
# [165.01, 132.01, 26.980000000000018, 96.98000000000002]
# [390.01, 101.01, 40.98000000000002, 125.98]
# [328.01, 231.01, 110.98000000000002, 51.98000000000002]
# [156.01, 247.01, 115.98000000000002, 89.98000000000002]
# [272.01, 198.01, 90.98000000000002, 34.98000000000002]
# [158.01, 118.01, 69.98000000000002, 96.98]
# [487.01, 176.01, 89.98000000000002, 69.98000000000002]
# [136.01, 159.01, 199.98000000000002, 153.98000000000002]
# [349.01, 64.01, 32.98000000000002, 138.98000000000002]
# [399.01, 125.01, 146.98000000000002, 309.98]
# [179.01, 109.01, 33.98000000000002, 103.98]
# [365.01, 109.01, 24.980000000000018, 93.98]
# [252.01, 81.01, 33.98000000000002, 122.98]
# [378.01, 147.01, 49.98000000000002, 42.98000000000002]
# [54.01, 221.01, 74.98000000000002, 137.98000000000002]
# [421.01, 108.01, 56.98000000000002, 219.98000000000002]
# [63.010000000000005, 210.01, 94.98, 72.98000000000002]
# [460.01, 66.01, 62.98000000000002, 169.98000000000002]
# [390.01, 164.01, 131.98000000000002, 122.98000000000002]
# [199.01, 80.01, 37.98000000000002, 139.98000000000002]
# [235.01, 156.01, 84.98000000000002, 71.98000000000002]
# [36.01, 233.01, 125.98000000000002, 225.98000000000002]
# [607.01, 117.01, 32.98000000000002, 127.98]
# [164.01, 156.01, 42.98000000000002, 47.98000000000002]
# [436.01, 142.01, 95.98000000000002, 126.98000000000002]
# [522.01, 212.01, 117.98000000000002, 135.98000000000002]
# [81.01, 132.01, 36.97999999999999, 54.98000000000002]
# [331.01, 61.01, 49.98000000000002, 127.98000000000002]
# [147.01, 244.01, 157.98000000000002, 103.98000000000002]
# [178.01, 164.01, 54.98000000000002, 43.98000000000002]
# [251.01, 205.01, 79.98000000000002, 55.98000000000002]
# [342.01, 151.01, 29.980000000000018, 54.98000000000002]
# [199.01, 6.01, 111.98000000000002, 337.98]
# [433.01, 173.01, 146.98000000000002, 106.98000000000002]
# [115.01, 71.01, 129.98000000000002, 179.98000000000002]
# [328.01, 111.01, 114.98000000000002, 64.98]
# [248.01, 284.01, 290.98, 143.98000000000002]
# [196.01, 187.01, 93.98000000000002, 83.98000000000002]
# [220.01, 124.01, 99.98000000000002, 72.98]
# [0, 348.01, 101.97999999999999, 126.98000000000002]
# [497.01, 159.01, 102.98000000000002, 50.98000000000002]
# [437.01, 140.01, 39.98000000000002, 143.98000000000002]
# [192.01, 94.01, 53.98000000000002, 118.98]
# [269.01, 131.01, 99.98000000000002, 120.98000000000002]
# [167.01, 0, 36.98000000000002, 164.98000000000002]
# [385.01, 14.01, 52.98000000000002, 199.98000000000002]
# [371.01, 405.01, 241.98000000000002, 74.98000000000002]
# [289.01, 0, 63.98000000000002, 253.98000000000002]
# [285.01, 170.01, 89.98000000000002, 80.98000000000002]
# [267.01, 189.01, 132.98000000000002, 113.98000000000002]
# [335.01, 82.01, 137.98000000000002, 89.98]
# [142.01, 38.01, 48.98000000000002, 136.98000000000002]
# [411.01, 461.01, 54.99000000000001, 18.980000000000018]
# [391.01, 99.01, 71.98000000000002, 52.980000000000004]
# [38.01, 97.01, 121.98000000000002, 146.98000000000002]
# [0, 245.01, 120.97999999999999, 182.98000000000002]
# [465.01, 333.01, 174.98000000000002, 79.98000000000002]
# [394.01, 130.01, 50.98000000000002, 80.98000000000002]
# [258.01, 170.01, 127.98000000000002, 107.98000000000002]
# [302.01, 165.01, 47.98000000000002, 103.98000000000002]
# [292.01, 124.01, 36.98000000000002, 95.98]
# [378.01, 82.01, 63.98000000000002, 99.98]
# [260.01, 174.01, 111.98000000000002, 62.98000000000002]
# [14.01, 193.01, 133.98000000000002, 72.98000000000002]
# [486.01, 65.01, 110.98000000000002, 331.98]
# [296.01, 98.01, 44.98000000000002, 143.98000000000002]
# [460.01, 185.01, 45.98000000000002, 62.98000000000002]
# [103.01, 147.01, 98.98, 99.98000000000002]
# [115.01, 114.01, 86.98, 91.98]
# [403.01, 133.01, 90.98000000000002, 60.98000000000002]
# [323.01, 194.01, 190.98000000000002, 282.98]
# [221.01, 241.01, 263.98, 148.98000000000002]
# [246.01, 41.01, 70.98000000000002, 148.98000000000002]
# [248.01, 211.01, 126.98000000000002, 37.98000000000002]
# [67.01, 257.01, 216.98000000000002, 176.98000000000002]
# [351.01, 78.01, 44.98000000000002, 106.98]
# [448.01, 73.01, 25.980000000000018, 96.98]
# [68.01, 149.01, 172.98000000000002, 106.98000000000002]
# [65.01, 243.01, 245.98000000000002, 224.98000000000002]
# [297.01, 99.01, 85.98000000000002, 72.98]
# [118.01, 257.01, 89.98, 133.98000000000002]
# [350.01, 93.01, 181.98000000000002, 191.98000000000002]
# [393.01, 101.01, 73.98000000000002, 105.98]
# [45.01, 252.01, 198.98000000000002, 68.98000000000002]
# [158.01, 122.01, 123.98000000000002, 109.98]
# [390.01, 45.01, 104.98000000000002, 217.98000000000002]
# [300.01, 69.01, 44.98000000000002, 173.98000000000002]
# [134.01, 186.01, 65.98000000000002, 78.98000000000002]
# [335.01, 166.01, 86.98000000000002, 56.98000000000002]
# [291.01, 190.01, 68.98000000000002, 108.98000000000002]
# [177.01, 164.01, 107.98000000000002, 60.98000000000002]
# [438.01, 130.01, 136.98000000000002, 105.98000000000002]
# [276.01, 199.01, 69.98000000000002, 42.98000000000002]
# [249.01, 158.01, 91.98000000000002, 71.98000000000002]
# [431.01, 90.01, 65.98000000000002, 135.98000000000002]
# [107.01, 211.01, 171.98000000000002, 81.98000000000002]
# [398.01, 122.01, 37.98000000000002, 116.98]
# [206.01, 120.01, 24.980000000000018, 121.98]
# [126.01, 92.01, 45.980000000000004, 146.98000000000002]
# [439.01, 108.01, 115.98000000000002, 151.98000000000002]
# [222.01, 177.01, 115.98000000000002, 72.98000000000002]
# [369.01, 198.01, 114.98000000000002, 66.98000000000002]
# [275.01, 97.01, 46.98000000000002, 125.98]
# [122.01, 52.01, 49.980000000000004, 154.98000000000002]
# [487.01, 158.01, 81.98000000000002, 78.98000000000002]
# [292.01, 147.01, 78.98000000000002, 174.98000000000002]
# [290.01, 147.01, 110.98000000000002, 332.98]
# [286.01, 94.01, 79.98000000000002, 58.980000000000004]
# [341.01, 123.01, 82.98000000000002, 60.980000000000004]
# [401.01, 121.01, 95.98000000000002, 205.98000000000002]
# [20.01, 220.01, 211.98000000000002, 246.98000000000002]
# [181.01, 165.01, 130.98000000000002, 45.98000000000002]
# [269.01, 70.01, 117.98000000000002, 90.98]
# [367.01, 236.01, 244.98000000000002, 202.98000000000002]
# [186.01, 163.01, 78.98000000000002, 130.98000000000002]
# [229.01, 179.01, 81.98000000000002, 35.98000000000002]
# [331.01, 233.01, 147.98000000000002, 69.98000000000002]
# [296.01, 208.01, 50.98000000000002, 37.98000000000002]
# [213.01, 101.01, 34.98000000000002, 190.98000000000002]
# [327.01, 173.01, 77.98000000000002, 37.98000000000002]
# [393.01, 129.01, 28.980000000000018, 100.98000000000002]
# [338.01, 128.01, 32.98000000000002, 133.98000000000002]
# [165.01, 143.01, 61.98000000000002, 97.98000000000002]
# [345.01, 141.01, 32.98000000000002, 56.98000000000002]
# [210.01, 188.01, 71.98000000000002, 67.98000000000002]
# [176.01, 151.01, 36.98000000000002, 53.98000000000002]
# [614.01, 86.01, 25.980000000000018, 376.98]
# [460.01, 143.01, 99.98000000000002, 60.98000000000002]
# [270.01, 140.01, 72.98000000000002, 227.98000000000002]
# [58.01, 160.01, 119.98000000000002, 61.98000000000002]
# [276.01, 212.01, 78.98000000000002, 34.98000000000002]
# [228.01, 87.01, 47.98000000000002, 120.98]
# [353.01, 162.01, 140.98000000000002, 158.98000000000002]
# [220.01, 96.01, 212.98000000000002, 188.98000000000002]
# [280.01, 117.01, 49.98000000000002, 195.98000000000002]
# [318.01, 111.01, 48.98000000000002, 88.98]
# [466.01, 88.01, 130.98000000000002, 391.98]
# [170.01, 143.01, 73.98000000000002, 60.98000000000002]
# [317.01, 167.01, 138.98000000000002, 51.98000000000002]
# [295.01, 107.01, 52.98000000000002, 139.98000000000002]
# [206.01, 220.01, 130.98000000000002, 57.98000000000002]
# [331.01, 156.01, 46.98000000000002, 65.98000000000002]
# [234.01, 57.01, 199.98000000000002, 200.98000000000002]
# [259.01, 156.01, 119.98000000000002, 105.98000000000002]
# [176.01, 175.01, 38.98000000000002, 65.98000000000002]
# [401.01, 195.01, 50.98000000000002, 55.98000000000002]
# [299.01, 128.01, 97.98000000000002, 89.98000000000002]
# [258.01, 237.01, 103.98000000000002, 61.98000000000002]
# [277.01, 157.01, 100.98000000000002, 90.98000000000002]
# [241.01, 132.01, 51.98000000000002, 56.98000000000002]
# [86.01, 28.01, 85.98, 247.98000000000002]
# [375.01, 127.00999999999999, 93.98000000000002, 58.98000000000002]
# [378.01, 174.01, 170.98000000000002, 124.98000000000002]
# [79.01, 229.01, 206.98000000000002, 250.98000000000002]
# [0, 390.01, 190.98000000000002, 89.98000000000002]
# [440.01, 185.01, 75.98000000000002, 111.98000000000002]
# [29.01, 142.01, 136.98000000000002, 65.98000000000002]
# [398.01, 136.01, 106.98000000000002, 36.98000000000002]
# [300.01, 116.01, 36.98000000000002, 124.98]
# [158.01, 186.01, 87.98000000000002, 78.98000000000002]
# [387.01, 87.01, 45.98000000000002, 134.98000000000002]
# [179.01, 111.01, 82.98000000000002, 66.98]
# [104.01, 184.01, 132.98000000000002, 113.98000000000002]
# [345.01, 123.01, 102.98000000000002, 297.98]
# [498.01, 22.01, 98.98000000000002, 201.98000000000002]
# [118.01, 57.01, 39.980000000000004, 136.98000000000002]
# [458.01, 66.01, 47.98000000000002, 138.98000000000002]
# [341.01, 326.01, 91.98000000000002, 153.98000000000002]
# [242.01, 217.01, 139.98000000000002, 71.98000000000002]
# [183.01, 56.01, 40.98000000000002, 117.98000000000002]
# [269.01, 33.01, 65.98000000000002, 183.98000000000002]
# [274.01, 0, 41.98000000000002, 155.98000000000002]
# [345.01, 191.01, 198.98000000000002, 288.98]
# [170.01, 144.01, 132.98000000000002, 124.98000000000002]
# [361.01, 113.01, 58.98000000000002, 122.98]
# [100.01, 251.01, 210.98000000000002, 116.98000000000002]
# [331.01, 151.01, 64.98000000000002, 48.98000000000002]
# [543.01, 151.01, 65.98000000000002, 132.98000000000002]
# [307.01, 145.01, 87.98000000000002, 85.98000000000002]
# [198.01, 145.01, 98.98000000000002, 61.98000000000002]
# [50.01, 155.01, 174.98000000000002, 146.98000000000002]
# [285.01, 71.01, 61.98000000000002, 172.98000000000002]
# [393.01, 152.01, 59.98000000000002, 122.98000000000002]
# [219.01, 178.01, 54.98000000000002, 42.98000000000002]
# [286.01, 171.01, 92.98000000000002, 78.98000000000002]
# [356.01, 160.01, 85.98000000000002, 46.98000000000002]
# [49.01, 181.01, 108.98000000000002, 65.98000000000002]
# [389.01, 194.01, 234.98000000000002, 169.98000000000002]
# [195.01, 161.01, 70.98000000000002, 64.98000000000002]
# [385.01, 223.01, 105.98000000000002, 60.98000000000002]
# [298.01, 172.01, 38.98000000000002, 84.98000000000002]
# [204.01, 165.01, 163.98000000000002, 134.98000000000002]
# [317.01, 182.01, 122.98000000000002, 297.98]
# [292.01, 109.01, 43.98000000000002, 57.980000000000004]
# [132.01, 138.01, 109.98000000000002, 82.98000000000002]
# [437.01, 136.01, 108.98000000000002, 102.98000000000002]
# [44.01, 169.01, 89.98000000000002, 38.98000000000002]
# [181.01, 223.01, 64.98000000000002, 256.98]
# [385.01, 48.01, 42.98000000000002, 183.98000000000002]
# [489.01, 127.00999999999999, 91.98000000000002, 94.98000000000002]
# [169.01, 177.01, 59.98000000000002, 40.98000000000002]
# [60.01, 279.01, 144.98000000000002, 95.98000000000002]
# [495.01, 179.01, 84.98000000000002, 46.98000000000002]
# [361.01, 193.01, 90.98000000000002, 105.98000000000002]
# [222.01, 139.01, 79.98000000000002, 37.98000000000002]
# [0, 337.01, 17.979999999999997, 88.98000000000002]
# [410.01, 75.01, 99.98000000000002, 129.98000000000002]
# [331.01, 169.01, 45.98000000000002, 54.98000000000002]
# [454.01, 197.01, 61.98000000000002, 34.98000000000002]
# [107.01, 84.01, 42.980000000000004, 131.98000000000002]
# [272.01, 147.01, 70.98000000000002, 216.98000000000002]
# [459.01, 179.01, 47.98000000000002, 31.980000000000018]
# [475.01, 147.01, 60.98000000000002, 135.98000000000002]
# [238.01, 182.01, 71.98000000000002, 56.98000000000002]
# [35.01, 169.01, 100.98000000000002, 77.98000000000002]
# [155.01, 200.01, 106.98000000000002, 106.98000000000002]
# [210.01, 152.01, 96.98000000000002, 53.98000000000002]
# [357.01, 155.01, 91.98000000000002, 178.98000000000002]
# [496.01, 398.01, 143.98000000000002, 81.98000000000002]
# [327.01, 151.01, 34.98000000000002, 40.98000000000002]
# [121.01, 115.01, 118.98, 85.98]
# [259.01, 111.01, 66.98000000000002, 102.98]
# [509.01, 33.01, 56.98000000000002, 230.98000000000002]
# [102.01, 55.01, 53.980000000000004, 202.98000000000002]
# [392.01, 35.01, 118.98000000000002, 314.98]
# [170.01, 140.01, 49.98000000000002, 76.98000000000002]
# [477.01, 157.01, 52.98000000000002, 43.98000000000002]
# [55.01, 116.01, 95.98000000000002, 223.98000000000002]
# [283.01, 206.01, 159.98000000000002, 84.98000000000002]
# [413.01, 116.01, 112.98000000000002, 72.98]
# [0, 139.01, 102.97999999999999, 159.98000000000002]
# [137.01, 212.01, 128.98000000000002, 229.98000000000002]
# [315.01, 119.01, 95.98000000000002, 61.980000000000004]
# [52.01, 88.01, 143.98000000000002, 167.98000000000002]
# [464.01, 129.01, 151.98000000000002, 105.98000000000002]
# [16.01, 226.01, 160.98000000000002, 70.98000000000002]
# [205.01, 153.01, 61.98000000000002, 78.98000000000002]
# [523.01, 39.01, 92.98000000000002, 179.98000000000002]
# [221.01, 26.01, 127.98000000000002, 229.98000000000002]
# [208.01, 144.01, 111.98000000000002, 121.98000000000002]
# [314.01, 153.01, 86.98000000000002, 76.98000000000002]
# [191.01, 37.01, 48.98000000000002, 140.98000000000002]
# [206.01, 33.01, 94.98000000000002, 262.98]
# [454.01, 123.01, 185.98000000000002, 250.98000000000002]
# [469.01, 86.01, 116.98000000000002, 163.98000000000002]
# [129.01, 5.01, 83.98000000000002, 217.98000000000002]
# [295.01, 41.01, 62.98000000000002, 203.98000000000002]
# [289.01, 172.01, 71.98000000000002, 70.98000000000002]
# [192.01, 32.01, 235.98000000000002, 266.98]
# [230.01, 277.01, 179.98000000000002, 94.98000000000002]
# [267.01, 153.01, 62.98000000000002, 51.98000000000002]
# [304.01, 200.01, 79.98000000000002, 41.98000000000002]
# [0, 0, 192.98000000000002, 480]
# ...
# [178.01, 140.01, 40.98000000000002, 55.98000000000002]
# [140.01, 208.01, 108.98000000000002, 90.98000000000002]
# [329.01, 187.01, 44.98000000000002, 51.98000000000002]
# [196.01, 376.01, 329.99, 103.98000000000002]
# [216.01, 99.01, 77.98000000000002, 67.98]
# [253.01, 79.01, 99.98000000000002, 191.98000000000002]
# [226.01, 0, 57.99000000000001, 138.98000000000002]
# [453.01, 415.01, 186.98000000000002, 64.98000000000002]
# [169.01, 124.01, 157.98000000000002, 131.98000000000002]
# [310.01, 131.01, 16.980000000000018, 107.98000000000002]
# [294.01, 98.01, 72.98000000000002, 152.98000000000002]
# [377.01, 111.01, 71.98000000000002, 92.98]
# [377.01, 128.01, 158.98000000000002, 210.98000000000002]
# [61.01, 172.01, 87.98000000000002, 89.98000000000002]
# [419.01, 143.01, 62.98000000000002, 107.98000000000002]
# [203.01, 96.01, 24.980000000000018, 118.98]
# [404.01, 123.01, 72.98000000000002, 92.98]
# [66.01, 60.01, 82.98, 270.98]
# [238.01, 84.01, 41.98000000000002, 131.98000000000002]
# [350.01, 102.01, 43.98000000000002, 159.98000000000002]
# [197.01, 115.01, 106.98000000000002, 97.98]
# [33.01, 249.01, 265.98, 196.98000000000002]
# [382.01, 163.01, 117.98000000000002, 39.98000000000002]
# [250.01, 117.01, 85.98000000000002, 56.980000000000004]
# [306.01, 322.01, 171.98000000000002, 157.98000000000002]
# [248.01, 170.01, 149.98000000000002, 95.98000000000002]
# [349.01, 144.01, 80.98000000000002, 89.98000000000002]
# [0, 191.01, 38.980000000000004, 56.98000000000002]
# [334.01, 130.01, 283.98, 250.98000000000002]
# [339.01, 123.01, 45.98000000000002, 57.980000000000004]
# [388.01, 37.01, 34.98000000000002, 149.98000000000002]
# [376.01, 83.01, 124.98000000000002, 287.98]
# [60.01, 143.01, 119.98000000000002, 117.98000000000002]
# [0, 263.01, 298.98, 141.98000000000002]
# [213.01, 82.01, 163.98000000000002, 48.980000000000004]
# [455.01, 200.01, 184.98000000000002, 232.98000000000002]
# [146.01, 217.01, 160.98000000000002, 64.98000000000002]
# [190.01, 141.01, 45.98000000000002, 55.98000000000002]
# [559.01, 153.01, 80.98000000000002, 143.98000000000002]
# [410.01, 111.01, 44.98000000000002, 112.98]
# [295.01, 125.01, 42.98000000000002, 61.980000000000004]
# [0, 233.01, 52.980000000000004, 246.98000000000002]
# [196.01, 305.01, 144.98000000000002, 174.98000000000002]
# [315.01, 42.01, 37.98000000000002, 139.98000000000002]
# [476.01, 142.01, 32.98000000000002, 86.98000000000002]
# [306.01, 48.01, 66.98000000000002, 169.98000000000002]
# [415.01, 202.01, 92.98000000000002, 181.98000000000002]
# [122.01, 145.01, 54.980000000000004, 55.98000000000002]
# [176.01, 154.01, 79.98000000000002, 154.98000000000002]
# [256.01, 189.01, 59.98000000000002, 32.98000000000002]
# [334.01, 106.01, 74.98000000000002, 170.98000000000002]
# [354.01, 123.01, 54.98000000000002, 126.98]
# [429.01, 211.01, 96.98000000000002, 268.98]
# [131.01, 64.01, 64.98000000000002, 138.98000000000002]
# [321.01, 108.01, 53.98000000000002, 79.98]
# [392.01, 143.01, 234.98000000000002, 230.98000000000002]
# [205.01, 131.01, 99.98000000000002, 67.98000000000002]
# [0, 137.01, 102.97999999999999, 342.98]
# [252.01, 153.01, 138.98000000000002, 151.98000000000002]
# [391.01, 58.01, 35.98000000000002, 89.98000000000002]
# [362.01, 89.01, 33.98000000000002, 122.98]
# [169.01, 110.01, 48.98000000000002, 113.98]
# [95.01, 64.01, 130.98000000000002, 289.98]
# [404.01, 183.01, 132.98000000000002, 62.98000000000002]
# [296.01, 160.01, 36.98000000000002, 82.98000000000002]
# [264.01, 126.01, 42.98000000000002, 64.98]
# [408.01, 154.01, 169.98000000000002, 126.98000000000002]
# [62.01, 133.01, 115.98000000000002, 259.98]
# [180.01, 158.01, 79.98000000000002, 87.98000000000002]
# [359.01, 162.01, 95.98000000000002, 43.98000000000002]
# [381.01, 205.01, 104.98000000000002, 76.98000000000002]
# [293.01, 37.01, 39.98000000000002, 143.98000000000002]
# [88.01, 126.01, 176.98000000000002, 185.98000000000002]
# [308.01, 259.01, 238.98000000000002, 159.98000000000002]
# [191.01, 120.01, 65.98000000000002, 103.98]
# [300.01, 133.01, 98.98000000000002, 69.98000000000002]
# [0, 263.01, 169.98000000000002, 109.98000000000002]
# [531.01, 217.01, 108.98000000000002, 130.98000000000002]
# [107.01, 84.01, 95.98, 106.98]
# [416.01, 126.01, 96.98000000000002, 73.98]
# [286.01, 76.01, 26.980000000000018, 131.98000000000002]
# [229.01, 254.01, 251.98000000000002, 129.98000000000002]
# [362.01, 44.01, 143.98000000000002, 165.98000000000002]
# [66.01, 238.01, 211.98000000000002, 104.98000000000002]
# [413.01, 0, 48.98000000000002, 209.98000000000002]
# [14.01, 195.01, 246.98000000000002, 138.98000000000002]
# [188.01, 133.01, 78.98000000000002, 133.98000000000002]
# [20.01, 216.01, 160.98000000000002, 156.98000000000002]
# [519.01, 103.01, 76.98000000000002, 113.98]
# [250.01, 140.01, 84.98000000000002, 68.98000000000002]
# [62.01, 13.01, 144.98000000000002, 285.98]
# [246.01, 136.01, 87.98000000000002, 60.98000000000002]
# [465.01, 135.01, 132.98000000000002, 137.98000000000002]
# [0, 128.01, 62.980000000000004, 124.98000000000002]
# [330.01, 168.01, 200.98000000000002, 166.98000000000002]
# [163.01, 149.01, 76.98000000000002, 63.98000000000002]
# [503.01, 154.01, 62.98000000000002, 81.98000000000002]
# [356.01, 110.01, 54.98000000000002, 100.98]
# [304.01, 135.01, 30.980000000000018, 104.98000000000002]
# [517.01, 112.01, 54.98000000000002, 169.98000000000002]
# [370.01, 141.01, 81.98000000000002, 61.98000000000002]
# [106.01, 136.01, 114.98, 60.98000000000002]
# [96.01, 293.01, 148.99, 186.98000000000002]
# [307.01, 126.01, 24.980000000000018, 116.98]
# [274.01, 169.01, 77.98000000000002, 76.98000000000002]
# [326.01, 166.01, 40.98000000000002, 46.98000000000002]
# [166.01, 153.01, 113.98000000000002, 91.98000000000002]
# [360.01, 206.01, 81.98000000000002, 99.98000000000002]
# [321.01, 111.01, 159.98000000000002, 229.98000000000002]
# [0, 159.01, 95.97999999999999, 129.98000000000002]
# [413.01, 103.01, 40.98000000000002, 81.98]
# [0, 377.01, 201.99, 102.98000000000002]
# [172.01, 0, 82.98000000000002, 187.98000000000002]
# [490.01, 0, 101.98000000000002, 187.98000000000002]
# [116.01, 184.01, 115.98, 101.98000000000002]
# [364.01, 101.01, 38.98000000000002, 135.98000000000002]
# [485.01, 103.01, 57.98000000000002, 124.98]
# [138.01, 170.01, 78.98000000000002, 67.98000000000002]
# [252.01, 139.01, 41.98000000000002, 94.98000000000002]
# [311.01, 186.01, 90.98000000000002, 70.98000000000002]
# [0, 120.01, 28.979999999999997, 157.98000000000002]
# [464.01, 155.01, 115.98000000000002, 62.98000000000002]
# [342.01, 164.01, 31.980000000000018, 92.98000000000002]
# [424.01, 128.01, 40.98000000000002, 126.98000000000002]
# [189.01, 181.01, 78.98000000000002, 48.98000000000002]
# [287.01, 200.01, 51.98000000000002, 47.98000000000002]
# [487.01, 181.01, 44.98000000000002, 46.98000000000002]
# [283.01, 194.01, 79.98000000000002, 33.98000000000002]
# [159.01, 233.01, 90.98000000000002, 84.98000000000002]
# [101.01, 108.01, 126.98, 133.98000000000002]
# [285.01, 152.01, 84.98000000000002, 65.98000000000002]
# [243.01, 192.01, 123.98000000000002, 85.98000000000002]
# [327.01, 154.01, 41.98000000000002, 78.98000000000002]
# [435.01, 160.01, 105.98000000000002, 74.98000000000002]
# [35.01, 154.01, 103.98000000000002, 61.98000000000002]
# [395.01, 248.01, 144.98000000000002, 151.98000000000002]
# [368.01, 155.01, 52.98000000000002, 75.98000000000002]
# [196.01, 196.01, 67.98000000000002, 76.98000000000002]
# [237.01, 50.01, 68.98000000000002, 258.98]
# [392.01, 145.01, 97.98000000000002, 72.98000000000002]
# [294.01, 132.01, 109.98000000000002, 118.98000000000002]
# [93.01, 158.01, 50.980000000000004, 46.98000000000002]
# [478.01, 36.01, 103.98000000000002, 262.98]
# [167.01, 221.01, 208.98000000000002, 125.98000000000002]
# [415.01, 436.01, 224.98000000000002, 43.98000000000002]
# [228.01, 0, 43.98000000000002, 127.97999999999999]
# [480.01, 137.01, 38.98000000000002, 75.98000000000002]
# [137.01, 178.01, 76.98000000000002, 36.98000000000002]
# [285.01, 197.01, 41.98000000000002, 129.98000000000002]
# [441.01, 103.01, 33.98000000000002, 169.98000000000002]
# [105.01, 200.01, 108.98, 52.98000000000002]
# [127.00999999999999, 109.01, 50.98000000000002, 114.98]
# [312.01, 156.01, 86.98000000000002, 204.98000000000002]
# [455.01, 66.01, 29.980000000000018, 148.98000000000002]
# [142.01, 151.01, 147.98000000000002, 52.98000000000002]
# [519.01, 41.01, 47.98000000000002, 191.98000000000002]
# [112.01, 254.01, 109.98, 135.98000000000002]
# [300.01, 149.01, 54.98000000000002, 93.98000000000002]
# [274.01, 192.01, 83.98000000000002, 65.98000000000002]
# [224.01, 0, 167.98000000000002, 373.98]
# [327.01, 136.01, 31.980000000000018, 49.98000000000002]
# [155.01, 117.01, 45.98000000000002, 102.98]
# [285.01, 125.01, 69.98000000000002, 84.98]
# [479.01, 63.010000000000005, 96.98000000000002, 289.98]
# [351.01, 56.01, 73.98000000000002, 198.98000000000002]
# [370.01, 60.01, 54.98000000000002, 157.98000000000002]
# [323.01, 148.01, 219.98000000000002, 168.98000000000002]
# [102.01, 163.01, 93.98, 63.98000000000002]
# [385.01, 109.01, 43.98000000000002, 123.98]
# [161.01, 186.01, 92.98000000000002, 79.98000000000002]
# [182.01, 40.01, 84.98000000000002, 261.98]
# [340.01, 171.01, 61.98000000000002, 41.98000000000002]
# [165.01, 93.01, 274.98, 191.98000000000002]
# [305.01, 148.01, 49.98000000000002, 95.98000000000002]
# [78.01, 162.01, 69.98, 43.98000000000002]
# [206.01, 136.01, 77.98000000000002, 146.98000000000002]
# [543.01, 105.01, 51.98000000000002, 83.98]
# [205.01, 308.01, 136.98000000000002, 171.98000000000002]
# [401.01, 135.01, 116.98000000000002, 98.98000000000002]
# [443.01, 135.01, 75.98000000000002, 176.98000000000002]
# [105.01, 159.01, 75.98, 51.98000000000002]
# [149.01, 70.01, 42.98000000000002, 123.98]
# [70.01, 269.01, 137.98000000000002, 129.98000000000002]
# [452.01, 160.01, 39.98000000000002, 56.98000000000002]
# [331.01, 215.01, 133.98000000000002, 57.98000000000002]
# [256.01, 95.01, 47.98000000000002, 86.98]
# [230.01, 238.01, 69.98000000000002, 140.98000000000002]
# [483.01, 129.01, 116.98000000000002, 154.98000000000002]
# [148.01, 135.01, 97.98000000000002, 97.98000000000002]
# [410.01, 172.01, 43.98000000000002, 62.98000000000002]
# [153.01, 146.01, 55.98000000000002, 125.98000000000002]
# [189.01, 170.01, 62.98000000000002, 73.98000000000002]
# [365.01, 104.01, 29.980000000000018, 170.98000000000002]
# [326.01, 117.01, 79.98000000000002, 106.98]
# [42.01, 288.01, 130.98000000000002, 104.98000000000002]
# [175.01, 89.01, 57.98000000000002, 96.98]
# [413.01, 190.01, 75.98000000000002, 227.98000000000002]
# [464.01, 126.01, 79.98000000000002, 65.98]
# [361.01, 101.01, 46.98000000000002, 98.98]
# [303.01, 251.01, 132.98000000000002, 130.98000000000002]
# [182.01, 169.01, 51.98000000000002, 69.98000000000002]
# [275.01, 158.01, 73.98000000000002, 83.98000000000002]
# [444.01, 21.01, 40.98000000000002, 158.98000000000002]
# [387.01, 132.01, 105.98000000000002, 234.98000000000002]
# [321.01, 140.01, 92.98000000000002, 111.98000000000002]
# [68.01, 224.01, 123.98, 96.98000000000002]
# [104.01, 145.01, 107.98, 76.98000000000002]
# [28.01, 165.01, 149.98000000000002, 122.98000000000002]
# [362.01, 74.01, 110.98000000000002, 75.98]
# [367.01, 215.01, 175.98000000000002, 264.98]
# [134.01, 230.01, 167.98000000000002, 116.98000000000002]
# [356.01, 188.01, 86.98000000000002, 42.98000000000002]
# [282.01, 168.01, 35.98000000000002, 49.98000000000002]
# [466.01, 187.01, 71.98000000000002, 61.98000000000002]
# [0, 218.01, 110.97999999999999, 53.98000000000002]
# [300.01, 212.01, 89.98000000000002, 51.98000000000002]
# [323.01, 183.01, 53.98000000000002, 30.980000000000018]
# [261.01, 186.01, 80.98000000000002, 57.98000000000002]
# [309.01, 121.01, 114.98000000000002, 121.98]
# [436.01, 0, 127.98000000000002, 384.98]
# [515.01, 64.01, 7.980000000000018, 54.97999999999999]
# [120.01, 77.01, 74.98, 105.98]
# [0, 233.01, 230.98000000000002, 170.98000000000002]
# [595.01, 211.01, 44.98000000000002, 140.98000000000002]
# [154.01, 79.01, 62.98000000000002, 98.98]
# [220.01, 83.01, 98.98000000000002, 211.98000000000002]
# [459.01, 52.01, 75.98000000000002, 146.98000000000002]
# [56.01, 66.01, 57.98, 145.98000000000002]
# [316.01, 339.01, 187.98000000000002, 140.98000000000002]
# [288.01, 173.01, 62.98000000000002, 66.98000000000002]
# [539.01, 56.01, 63.98000000000002, 162.98000000000002]
# [35.01, 249.01, 222.98000000000002, 88.98000000000002]
# [571.01, 241.01, 68.98000000000002, 228.98000000000002]
# [111.01, 17.01, 61.980000000000004, 122.98]
# [420.01, 266.01, 219.98000000000002, 108.98000000000002]
# [235.01, 159.01, 87.98000000000002, 32.98000000000002]
# [265.01, 189.01, 74.98000000000002, 60.98000000000002]
# [40.01, 89.01, 64.97999999999999, 154.98000000000002]
# [452.01, 140.01, 55.98000000000002, 127.98000000000002]
# [299.01, 174.01, 163.98000000000002, 81.98000000000002]
# [315.01, 0, 178.98000000000002, 477.98]
# [251.01, 118.01, 52.98000000000002, 55.980000000000004]
# [290.01, 86.01, 51.98000000000002, 156.98000000000002]
# [342.01, 347.01, 85.98000000000002, 132.98000000000002]
# [217.01, 161.01, 61.98000000000002, 44.98000000000002]
# [147.01, 134.01, 94.98000000000002, 123.98000000000002]
# [448.01, 97.01, 24.980000000000018, 100.98]
# [431.01, 73.01, 80.98000000000002, 265.98]
# [493.01, 25.01, 24.980000000000018, 101.97999999999999]
# [0, 303.01, 102.97999999999999, 120.98000000000002]
# [141.01, 77.01, 37.98000000000002, 123.98]
# [166.01, 92.01, 60.98000000000002, 117.98]
# [474.01, 321.01, 165.98000000000002, 158.98000000000002]
# [398.01, 0.010000000000000009, 57.98000000000002, 161.98000000000002]
# [40.01, 267.01, 86.97999999999999, 103.98000000000002]
# [278.01, 183.01, 82.98000000000002, 68.98000000000002]
# [245.01, 161.01, 97.98000000000002, 34.98000000000002]
# [41.01, 129.01, 140.98000000000002, 313.98]
# [400.01, 188.01, 95.98000000000002, 88.98000000000002]
# [165.01, 110.01, 126.98000000000002, 139.98000000000002]
# [377.01, 136.01, 99.98000000000002, 63.98000000000002]
# [145.01, 176.01, 79.98000000000002, 100.98000000000002]
# [458.01, 314.01, 152.98000000000002, 165.98000000000002]
# [351.01, 180.01, 127.98000000000002, 37.98000000000002]
# [250.01, 142.01, 45.98000000000002, 34.98000000000002]
# [175.01, 148.01, 80.98000000000002, 72.98000000000002]
# [257.01, 64.01, 114.98000000000002, 110.98]
# [482.01, 403.01, 157.98000000000002, 76.98000000000002]
# [269.01, 201.01, 94.98000000000002, 52.98000000000002]
# [76.01, 145.01, 119.98, 334.98]
# [545.01, 206.01, 94.98000000000002, 107.98000000000002]
# [278.01, 94.01, 147.98000000000002, 119.98]
# [300.01, 53.01, 120.98000000000002, 108.98000000000002]
# [80.01, 91.01, 80.98, 78.98]
# [217.01, 95.01, 87.98000000000002, 74.98]
# [457.01, 83.01, 66.98000000000002, 146.98000000000002]
# [211.01, 155.01, 111.98000000000002, 130.98000000000002]
# [39.01, 345.01, 369.98, 134.98000000000002]
# [0, 118.01, 67.97999999999999, 256.98]
# [395.01, 104.01, 42.98000000000002, 91.98]
# [431.01, 193.01, 89.98000000000002, 73.98000000000002]
# [274.01, 347.01, 134.98000000000002, 132.98000000000002]
# [273.01, 159.01, 63.98000000000002, 64.98000000000002]
# [35.01, 50.01, 73.97999999999999, 159.98000000000002]
# [394.01, 167.01, 79.98000000000002, 40.98000000000002]
# [0, 355.01, 78.97999999999999, 124.98000000000002]
# [420.01, 36.01, 39.98000000000002, 126.98000000000002]
# [205.01, 187.01, 82.98000000000002, 63.98000000000002]
# [387.01, 90.01, 27.980000000000018, 140.98000000000002]
# [274.01, 89.01, 67.98000000000002, 72.98]
# [321.01, 257.01, 104.98000000000002, 222.98000000000002]
# [321.01, 30.01, 67.98000000000002, 202.98000000000002]
# [357.01, 306.01, 102.98000000000002, 167.98000000000002]
# [205.01, 0, 59.98000000000002, 177.98000000000002]
# [221.01, 101.01, 44.98000000000002, 131.98000000000002]
# [494.01, 116.01, 25.980000000000018, 96.98]
# [8.01, 148.01, 160.98000000000002, 137.98000000000002]
# [274.01, 181.01, 115.98000000000002, 84.98000000000002]
# [63.010000000000005, 154.01, 93.98, 156.98000000000002]
# [141.01, 132.01, 104.98000000000002, 60.98000000000002]
# [267.01, 253.01, 127.98000000000002, 171.98000000000002]
# [438.01, 77.01, 120.98000000000002, 105.98]
# [387.01, 70.01, 53.98000000000002, 190.98000000000002]
# [276.01, 163.01, 91.98000000000002, 76.98000000000002]
# [191.01, 160.01, 76.98000000000002, 44.98000000000002]
# KeyboardInterrupt
# Error in callback <function flush_figures at 0x18e207d00> (for post_execute):
# KeyboardInterrupt
